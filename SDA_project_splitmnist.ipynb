# %%
# installing the avalanche library
# !pip install avalanche-lib==0.3.1
# Out:
# Collecting avalanche-lib==0.3.1
#   Downloading avalanche_lib-0.3.1-py3-none-any.whl (811 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 811.0/811.0 kB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from avalanche-lib==0.3.1) (4.5.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from avalanche-lib==0.3.1) (5.9.5)
# Collecting gputil (from avalanche-lib==0.3.1)
#   Downloading GPUtil-1.4.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from avalanche-lib==0.3.1) (1.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from avalanche-lib==0.3.1) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from avalanche-lib==0.3.1) (1.23.5)
# Collecting pytorchcv (from avalanche-lib==0.3.1)
#   Downloading pytorchcv-0.0.67-py2.py3-none-any.whl (532 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.4/532.4 kB 48.2 MB/s eta 0:00:00
# Collecting wandb (from avalanche-lib==0.3.1)
#   Downloading wandb-0.15.12-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 65.2 MB/s eta 0:00:00
# Requirement already satisfied: tensorboard>=1.15 in /usr/local/lib/python3.10/dist-packages (from avalanche-lib==0.3.1) (2.13.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from avalanche-lib==0.3.1) (4.66.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from avalanche-lib==0.3.1) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from avalanche-lib==0.3.1) (0.15.2+cu118)
# Collecting torchmetrics (from avalanche-lib==0.3.1)
#   Downloading torchmetrics-1.2.0-py3-none-any.whl (805 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 805.2/805.2 kB 60.2 MB/s eta 0:00:00
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (from avalanche-lib==0.3.1) (4.6.6)
# Collecting quadprog (from avalanche-lib==0.3.1)
#   Downloading quadprog-0.1.11-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (452 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.8/452.8 kB 34.9 MB/s eta 0:00:00
# Collecting dill (from avalanche-lib==0.3.1)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 12.0 MB/s eta 0:00:00
# Collecting setuptools<=59.5.0 (from avalanche-lib==0.3.1)
#   Downloading setuptools-59.5.0-py3-none-any.whl (952 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.4/952.4 kB 70.9 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->avalanche-lib==0.3.1) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->avalanche-lib==0.3.1) (1.59.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->avalanche-lib==0.3.1) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->avalanche-lib==0.3.1) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->avalanche-lib==0.3.1) (3.5)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->avalanche-lib==0.3.1) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->avalanche-lib==0.3.1) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->avalanche-lib==0.3.1) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->avalanche-lib==0.3.1) (3.0.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->avalanche-lib==0.3.1) (0.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown->avalanche-lib==0.3.1) (3.12.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown->avalanche-lib==0.3.1) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown->avalanche-lib==0.3.1) (4.11.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->avalanche-lib==0.3.1) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->avalanche-lib==0.3.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->avalanche-lib==0.3.1) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->avalanche-lib==0.3.1) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->avalanche-lib==0.3.1) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->avalanche-lib==0.3.1) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->avalanche-lib==0.3.1) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->avalanche-lib==0.3.1) (2.8.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->avalanche-lib==0.3.1) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->avalanche-lib==0.3.1) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->avalanche-lib==0.3.1) (3.2.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->avalanche-lib==0.3.1) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->avalanche-lib==0.3.1) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->avalanche-lib==0.3.1) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch->avalanche-lib==0.3.1) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->avalanche-lib==0.3.1) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch->avalanche-lib==0.3.1) (17.0.2)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics->avalanche-lib==0.3.1)
#   Downloading lightning_utilities-0.9.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb->avalanche-lib==0.3.1) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb->avalanche-lib==0.3.1)
#   Downloading GitPython-3.1.38-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 20.7 MB/s eta 0:00:00
# Collecting sentry-sdk>=1.0.0 (from wandb->avalanche-lib==0.3.1)
#   Downloading sentry_sdk-1.32.0-py2.py3-none-any.whl (240 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.0/241.0 kB 26.9 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb->avalanche-lib==0.3.1)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from wandb->avalanche-lib==0.3.1) (6.0.1)
# Collecting pathtools (from wandb->avalanche-lib==0.3.1)
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb->avalanche-lib==0.3.1)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb->avalanche-lib==0.3.1) (1.4.4)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb->avalanche-lib==0.3.1)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.9 MB/s eta 0:00:00
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15->avalanche-lib==0.3.1) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15->avalanche-lib==0.3.1) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15->avalanche-lib==0.3.1) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=1.15->avalanche-lib==0.3.1) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=1.15->avalanche-lib==0.3.1) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=1.15->avalanche-lib==0.3.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=1.15->avalanche-lib==0.3.1) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=1.15->avalanche-lib==0.3.1) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=1.15->avalanche-lib==0.3.1) (2.1.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown->avalanche-lib==0.3.1) (2.5)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard>=1.15->avalanche-lib==0.3.1) (1.7.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->avalanche-lib==0.3.1) (1.3.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->avalanche-lib==0.3.1)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=1.15->avalanche-lib==0.3.1) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=1.15->avalanche-lib==0.3.1) (3.2.2)
# Building wheels for collected packages: gputil, pathtools
#   Building wheel for gputil (setup.py) ... done
#   Created wheel for gputil: filename=GPUtil-1.4.0-py3-none-any.whl size=7392 sha256=65f762655a73013727dc37ba6f5ca7706a8f8e8e4153cbc7b4e66992bdfbafcb
#   Stored in directory: /root/.cache/pip/wheels/a9/8a/bd/81082387151853ab8b6b3ef33426e98f5cbfebc3c397a9d4d0
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=315b2e57886ea4611d7c04f490c1ea8bbfeafe61574459cba0093b234637a317
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built gputil pathtools
# Installing collected packages: pathtools, gputil, smmap, setuptools, setproctitle, sentry-sdk, quadprog, lightning-utilities, docker-pycreds, dill, pytorchcv, gitdb, GitPython, wandb, torchmetrics, avalanche-lib
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.7.2
#     Uninstalling setuptools-67.7.2:
#       Successfully uninstalled setuptools-67.7.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# arviz 0.15.1 requires setuptools>=60.0.0, but you have setuptools 59.5.0 which is incompatible.
# cvxpy 1.3.2 requires setuptools>65.5.1, but you have setuptools 59.5.0 which is incompatible.
# Successfully installed GitPython-3.1.38 avalanche-lib-0.3.1 dill-0.3.7 docker-pycreds-0.4.0 gitdb-4.0.10 gputil-1.4.0 lightning-utilities-0.9.0 pathtools-0.1.2 pytorchcv-0.0.67 quadprog-0.1.11 sentry-sdk-1.32.0 setproctitle-1.3.3 setuptools-59.5.0 smmap-5.0.1 torchmetrics-1.2.0 wandb-0.15.12

# %%
# importing pytorch and SGD optimizer
import torch
import torchvision
from torch.optim import SGD
from torch.nn import CrossEntropyLoss
# importing splitmnist benchmark
from avalanche.benchmarks.classic import SplitMNIST
# importing models and plugins and evaluation metrics
# using simpleMLP and PNN as a base models
from avalanche.training.plugins import EarlyStoppingPlugin
from avalanche.models import SimpleMLP,PNN
from avalanche.training.supervised import Naive, Replay, GDumb, LwF , EWC , CWRStar, PNNStrategy,GEM   # and many more!
# the way we can save the evaluation log in txt for other formats
from avalanche.training.plugins import EvaluationPlugin
from avalanche.logging import InteractiveLogger,TextLogger
from avalanche.evaluation.metrics import accuracy_metrics,\
    cpu_usage_metrics,forward_transfer_metrics,bwt_metrics,\
    ram_usage_metrics, timing_metrics,\
    StreamForwardTransfer,StreamBWT
import matplotlib.pyplot as plt
import numpy as np
import statistics
import os

# %% [markdown]
# #**Model creating and preprocessing part:**

# %%
# this part is related to mounting google drive in Colab, if you are using a local environment then discard it
from google.colab import drive
drive.mount('/drive')
# !ls/drive/my\drive
# Out:
# Mounted at /drive
# /bin/bash: line 1: ls/drive/mydrive: No such file or directory

# %%
# loading the benchmark and considering 5 experiences
split_mnist = SplitMNIST(n_experiences=5,return_task_id=True, seed=13)
print('--- Task labels:')
print(split_mnist.task_labels)

loggers = []

# log to text file
loggers.append(TextLogger(open('naive_log.txt', 'a')))

# print to stdout
loggers.append(InteractiveLogger())


# loading the model
model = SimpleMLP(num_classes=10)
# defining the optimizer with constant parameters
optimizer = SGD(model.parameters(), lr=0.001, momentum=0.9)
# defining the loss function
criterion = CrossEntropyLoss()
# here the evaluation plugin defined
eval_plugin = EvaluationPlugin(
    accuracy_metrics(experience=True),
    bwt_metrics(experience=True),
    forward_transfer_metrics(experience=True),
    timing_metrics(experience=True,stream=True),
    cpu_usage_metrics(experience=True,stream=True),
    ram_usage_metrics(experience=True, stream=True),
    StreamForwardTransfer(),
    StreamBWT(),

        loggers=loggers,
        collect_all=False,
        strict_checks=False
)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /root/.avalanche/data/mnist/TensorMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 58847182.88it/s]
# Extracting /root/.avalanche/data/mnist/TensorMNIST/raw/train-images-idx3-ubyte.gz to /root/.avalanche/data/mnist/TensorMNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /root/.avalanche/data/mnist/TensorMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 32148538.70it/s]
# Extracting /root/.avalanche/data/mnist/TensorMNIST/raw/train-labels-idx1-ubyte.gz to /root/.avalanche/data/mnist/TensorMNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /root/.avalanche/data/mnist/TensorMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 26564741.61it/s]
# Extracting /root/.avalanche/data/mnist/TensorMNIST/raw/t10k-images-idx3-ubyte.gz to /root/.avalanche/data/mnist/TensorMNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /root/.avalanche/data/mnist/TensorMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 4360386.53it/s]
# Extracting /root/.avalanche/data/mnist/TensorMNIST/raw/t10k-labels-idx1-ubyte.gz to /root/.avalanche/data/mnist/TensorMNIST/raw
#
# --- Task labels:
# [[0], [1], [2], [3], [4]]

# %% [markdown]
# ##**Naive aproach:**

# %%
"""
We are defining Naive strategy. here our model is SimpleMLP and the optimizer is SGD.
train_mb_size is training mini-batch size and considered 100 samples. this means we train the model with 100 samples, compute the SGD
and then train the model with the following 100 samples. if we select a higher value for batch, the training phase finishes
early but maybe our model doesn't converge to the global minimum. This is a hyperparameter and must be tuned during the training phase.
for simplicity, we are considering the constant value for it.

The next parameter is train_epoch, this is the number of training iterations on the same data. we considered it
as a fixed value 10 epoches.eval_mb_size is batch size for evaluation part.

In all the strategies we are evaluating our model based on different metrics and these metrics saved in eval_plugin.
Here the eval_every parameter set to 1. the frequency of the calls to eval inside the training loop. -1 disables the
evaluation. 0 means eval is called only at the end of the learning experience. Values >0 mean that eval is called every eval_every
epochs and at the end of the learning experience.

finally we set plugins that we need. here just we are using early stopping. We are training our model in fixed number of epoches.
for preventing overfitting we are using earlystopping with patience=3.
this means if in the next 3 iterations, the training loss doesn't decrease then stop the training.
"""
cl_strategy = Naive(
    model, optimizer,
    CrossEntropyLoss(), train_mb_size=512, train_epochs=10, eval_mb_size=512,
    evaluator=eval_plugin,eval_every=1,
     plugins=[EarlyStoppingPlugin(patience=3, val_stream_name='train')])

# %%
# saving the results of evaluation.
results = []

for experience in split_mnist.train_stream:
    # train returns a dictionary which contains all the metric values
    print("Start of experience::::: ", experience.current_experience)
    print("Current Classes::::: ", experience.classes_in_this_experience)
    cl_strategy.train(experience,eval_streams=[split_mnist.test_stream])
    print('Training completed')

    print('Computing accuracy on the whole test set')
    # test also returns a dictionary which contains all the metric values
    results.append(cl_strategy.eval(experience))
    print('Validation on test sets are completed')

# %% [markdown]
# # **Replay**

# %%
# loading the benchmark and considering 5 experiences
split_mnist = SplitMNIST(n_experiences=5,return_task_id=True, seed=13)
print('--- Task labels:')
print(split_mnist.task_labels)

loggers = []

# log to text file
loggers.append(TextLogger(open('replay_log.txt', 'a')))

# print to stdout
loggers.append(InteractiveLogger())


# loading the model
model = SimpleMLP(num_classes=10)
# defining the optimizer with constant parameters
optimizer = SGD(model.parameters(), lr=0.001, momentum=0.9)
# defining the loss function
criterion = CrossEntropyLoss()
# here the evaluation plugin defined
eval_plugin = EvaluationPlugin(
    accuracy_metrics(experience=True),
    bwt_metrics(experience=True),
    forward_transfer_metrics(experience=True),
    timing_metrics(experience=True,stream=True),
    cpu_usage_metrics(experience=True,stream=True),
    ram_usage_metrics( experience=True, stream=True),
    StreamForwardTransfer(),
    StreamBWT(),

        loggers=loggers,
        collect_all=False,
        strict_checks=False
)

cl_strategy = Replay(
    model, optimizer,
    CrossEntropyLoss(), train_mb_size=512, train_epochs=10, eval_mb_size=512,
    evaluator=eval_plugin,eval_every=1,
     plugins=[EarlyStoppingPlugin(patience=3, val_stream_name='train')])
# Out:
# --- Task labels:
# [[0], [1], [2], [3], [4]]

# %%
# saving the results of evaluation.
results = []

for experience in split_mnist.train_stream:
    # train returns a dictionary which contains all the metric values
    print("Start of experience::::: ", experience.current_experience)
    print("Current Classes::::: ", experience.classes_in_this_experience)
    cl_strategy.train(experience,eval_streams=[split_mnist.test_stream])
    print('Training completed')

    print('Computing accuracy on the whole test set')
    # test also returns a dictionary which contains all the metric values
    results.append(cl_strategy.eval(experience))
    print('Validation on test sets are completed')
# Out:
# Start of experience:::::  0
# Current Classes:::::  [8, 5]
# -- >> Start of training phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.36it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.8989
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3510
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.1897
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.43it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 99.5569
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3516
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0052
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.09it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 97.2437
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1181.1172
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3910
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.2924
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.86it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 96.5855
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.3935
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0028
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.14it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 95.5929
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1181.1172
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4398
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0174
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.7421
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1181.1172
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0790
# 100%|██████████| 23/23 [00:03<00:00,  6.49it/s]
# Epoch 0 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.08it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 91.5778
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5681
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8767
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:01<00:00,  3.62it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 94.1208
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1181.1172
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 1.1049
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.10it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 94.8985
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.3906
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6533
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.26it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 94.1574
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4887
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.31it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 99.2369
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.3906
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3529
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 93.9303
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1181.1172
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.3534
# 100%|██████████| 23/23 [00:02<00:00,  9.06it/s]
# Epoch 1 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.00it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.2970
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3636
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9325
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.23it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 98.6488
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3550
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.08it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.7640
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.3906
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3930
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.94it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 99.7002
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.3914
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.99it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 96.7953
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.3906
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3619
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.6126
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.3906
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0079
# 100%|██████████| 23/23 [00:02<00:00,  9.14it/s]
# Epoch 2 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.56it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 92.4740
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5300
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9448
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.10it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 93.9676
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5642
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.15it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 93.2343
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5578
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.70it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.4492
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5765
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.60it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 96.9298
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5263
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 93.7912
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.3984
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.9214
# 100%|██████████| 23/23 [00:03<00:00,  6.11it/s]
# Epoch 3 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.88it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 101.2018
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3657
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9518
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.11it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 97.4812
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3592
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.72it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 101.9164
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3731
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.21it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 99.5536
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4120
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.79it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 97.0997
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3710
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 97.7967
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.3984
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0246
# 100%|██████████| 23/23 [00:02<00:00,  9.64it/s]
# Epoch 4 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.30it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 92.7278
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3561
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9566
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.70it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 96.2464
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3742
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.54it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 99.7568
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3810
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.61it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 97.5476
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4000
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.01it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 97.2571
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3601
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.8999
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.3984
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0126
# 100%|██████████| 23/23 [00:03<00:00,  6.39it/s]
# Epoch 5 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.75it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.6296
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5900
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9625
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.17it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 93.8667
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.6502
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.95it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 93.7870
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6719
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.42it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 93.8275
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5330
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.90it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 99.6626
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4014
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.1453
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.3984
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.0274
# 100%|██████████| 23/23 [00:02<00:00,  9.52it/s]
# Epoch 6 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.42it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 99.4064
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3522
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9636
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.82it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 101.2505
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3656
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.31it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 94.9164
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3900
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.31it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 96.2591
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4052
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.37it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 99.3261
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3827
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.4834
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.3984
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0525
# 100%|██████████| 23/23 [00:03<00:00,  7.43it/s]
# Epoch 7 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.45it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 91.0655
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5382
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9636
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.05it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 91.6528
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5677
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.85it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 90.3673
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5866
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.99it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 92.2853
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6287
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.08it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 94.3954
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.6570
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 90.4102
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.3984
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.1750
# 100%|██████████| 23/23 [00:02<00:00,  8.41it/s]
# Epoch 8 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.90it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 97.7907
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3683
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9646
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.36it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 97.3678
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3493
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.86it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 97.1266
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4122
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.40it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.9402
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4066
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.77it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 100.2483
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3693
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 97.0902
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.3984
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0394
# 100%|██████████| 23/23 [00:02<00:00,  9.12it/s]
# Epoch 9 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.22it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 95.6825
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3555
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9646
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.48it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 96.7066
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4270
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.34it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 97.6870
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3892
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.08it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 98.4210
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4168
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.45it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 92.9399
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3875
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.6621
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.3984
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.1106
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from train stream --
# 100%|██████████| 23/23 [00:03<00:00,  7.42it/s]
# > Eval on experience 0 (Task 0) from train stream ended.
# 	CPUUsage_Exp/eval_phase/train_stream/Task000/Exp000 = 94.2070
# 	MaxRAMUsage_Experience/eval_phase/train_stream/Task000/Exp000 = 1091.3984
# 	Time_Exp/eval_phase/train_stream/Task000/Exp000 = 3.0996
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp000 = 0.9597
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/train_stream/Task000 = 94.0162
# 	MaxRAMUsage_Stream/eval_phase/train_stream/Task000 = 1091.3984
# 	StreamBWT/eval_phase/train_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/train_stream = 0.0000
# 	Time_Stream/eval_phase/train_stream/Task000 = 3.1061
# Validation on test sets are completed
# Start of experience:::::  1
# Current Classes:::::  [4, 6]
# -- >> Start of training phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.79it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 97.4572
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3387
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9646
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.92it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 97.5699
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3704
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.43it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.9308
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4279
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 11.79it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 94.3596
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4241
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.06it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 100.5337
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3980
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.9469
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.3984
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0940
# 100%|██████████| 23/23 [00:03<00:00,  6.82it/s]
# Epoch 0 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.33it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 89.5857
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.4646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3908
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.83it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 97.9434
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3678
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9588
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.91it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 92.5121
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4110
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.73it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.9043
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4695
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.05it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 96.8972
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4026
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 93.6693
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.3984
# 	StreamBWT/eval_phase/test_stream = -0.4646
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.1991
# 100%|██████████| 23/23 [00:05<00:00,  4.51it/s]
# Epoch 1 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.70it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 95.0716
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.2240
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5998
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.7406
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.35it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 93.1666
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4295
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9706
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.23it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 99.5843
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3917
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 11.94it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 94.9948
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4212
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.23it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 97.9152
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3985
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.0615
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.3984
# 	StreamBWT/eval_phase/test_stream = -0.2240
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.4093
# 100%|██████████| 23/23 [00:03<00:00,  6.75it/s]
# Epoch 2 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.51it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 94.5963
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0943
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3808
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8703
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.29it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 93.4646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3854
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9603
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.61it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 93.0494
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4193
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.65it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.7759
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4701
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.28it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 101.3137
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3852
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.0278
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.3984
# 	StreamBWT/eval_phase/test_stream = -0.0943
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.1993
# 100%|██████████| 23/23 [00:04<00:00,  4.83it/s]
# Epoch 3 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.71it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 87.8924
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0836
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.6030
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8810
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  4.02it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 61.2717
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9956
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9639
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.86it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 89.5188
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6815
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  6.86it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 90.3439
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.7306
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.04it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 95.1513
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4942
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 81.5410
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.3984
# 	StreamBWT/eval_phase/test_stream = -0.0836
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.7281
# 100%|██████████| 23/23 [00:03<00:00,  6.69it/s]
# Epoch 4 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.44it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 98.5440
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0761
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3858
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8885
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.86it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 96.6734
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3726
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9655
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.51it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 97.5667
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4205
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 11.27it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 91.7664
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4469
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.61it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 97.4139
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4211
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.7641
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.3984
# 	StreamBWT/eval_phase/test_stream = -0.0761
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.2033
# 100%|██████████| 23/23 [00:03<00:00,  6.25it/s]
# Epoch 5 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.36it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 88.2024
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0750
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5443
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8896
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.86it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 91.0322
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5826
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9660
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.35it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 93.9383
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5430
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.47it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 92.8258
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1091.3984
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5927
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.27it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 94.7426
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5491
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 91.7875
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.3984
# 	StreamBWT/eval_phase/test_stream = -0.0750
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.9743
# 100%|██████████| 23/23 [00:05<00:00,  4.59it/s]
# Epoch 6 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.52it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 97.6541
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0686
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3484
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8960
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.10it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 100.2114
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3994
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9680
# ...
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 90.2537
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.1978
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.4023
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5764
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.7556
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.95it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.1851
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.4571
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5040
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5247
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.36it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 100.3474
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.4023
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4786
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9811
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 87.9219
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4023
# 	StreamBWT/eval_phase/test_stream = -0.3007
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.1502
# 100%|██████████| 24/24 [00:03<00:00,  6.27it/s]
# Epoch 5 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.02it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 94.3965
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.3146
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4452
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.6501
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.55it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 96.1193
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.1907
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4683
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.7814
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.53it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 93.2212
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.1915
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4723
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.7620
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.27it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.3243
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.4137
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1091.4023
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4934
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5681
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.39it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 91.4306
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4815
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9816
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 93.6212
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4023
# 	StreamBWT/eval_phase/test_stream = -0.2776
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.5421
# 100%|██████████| 24/24 [00:05<00:00,  4.74it/s]
# Epoch 6 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.13it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 91.1278
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.2894
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4938
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.6752
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.78it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 84.9272
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.1820
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1091.4023
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5889
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.7902
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.10it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 79.8792
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.1836
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6512
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.7698
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  6.29it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 81.4539
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.3624
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1091.4023
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.7979
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6194
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.81it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 79.5684
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.4023
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.6916
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9806
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 82.1724
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4023
# 	StreamBWT/eval_phase/test_stream = -0.2543
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.4072
# 100%|██████████| 24/24 [00:03<00:00,  6.26it/s]
# Epoch 7 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.83it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.0181
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.2781
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4584
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.6865
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.81it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 94.2813
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.1763
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4566
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.7959
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.10it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 94.9978
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.1792
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4948
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.7742
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.76it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.3961
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.3106
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1091.4023
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5137
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6712
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.34it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 96.2579
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4780
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9811
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.7063
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4023
# 	StreamBWT/eval_phase/test_stream = -0.2361
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.5657
# 100%|██████████| 24/24 [00:04<00:00,  5.39it/s]
# Epoch 8 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.83it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 81.3359
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.2669
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5902
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.6977
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.46it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 82.6189
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.1747
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1091.4023
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.6175
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.7974
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.18it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 77.9702
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.1783
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6542
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.7752
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.15it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 89.5593
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.2799
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6142
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.7020
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.09it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 82.5694
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.4023
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.6543
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9821
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 81.7057
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4023
# 	StreamBWT/eval_phase/test_stream = -0.2249
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.3175
# 100%|██████████| 24/24 [00:04<00:00,  5.04it/s]
# Epoch 9 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.31it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.9124
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.2583
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4335
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.7063
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.35it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 93.5979
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.1778
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4808
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.7943
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.58it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 98.9383
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.1734
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4652
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.7801
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.34it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 93.2792
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.2575
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1091.4023
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5363
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.7243
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.32it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 96.2684
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4778
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9826
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.1560
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4023
# 	StreamBWT/eval_phase/test_stream = -0.2167
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.5432
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 4 (Task 4) from train stream --
# 100%|██████████| 24/24 [00:02<00:00,  8.67it/s]
# > Eval on experience 4 (Task 4) from train stream ended.
# 	CPUUsage_Exp/eval_phase/train_stream/Task004/Exp004 = 96.9870
# 	MaxRAMUsage_Experience/eval_phase/train_stream/Task004/Exp004 = 1091.4023
# 	Time_Exp/eval_phase/train_stream/Task004/Exp004 = 2.7633
# 	Top1_Acc_Exp/eval_phase/train_stream/Task004/Exp004 = 0.9858
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/train_stream/Task004 = 97.0110
# 	MaxRAMUsage_Stream/eval_phase/train_stream/Task004 = 1091.4023
# 	StreamBWT/eval_phase/train_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/train_stream = -0.0174
# 	Time_Stream/eval_phase/train_stream/Task004 = 2.7731
# Validation on test sets are completed

# %% [markdown]
# # **GDumb**

# %%
'''GDUMB, on the other hand, involves unlearning some of the weights of the network that are specific to the previous
tasks before learning the new task. The unlearning is done using a form of memory-bounded backpropagation that selectively
removes weights associated with previous tasks that are no longer relevant to the current task. This approach can also be
effective in mitigating catastrophic forgetting, as it helps to reduce the interference between the weights associated with
previous tasks and those associated with the current task.
'''

# %%
# loading the benchmark and considering 5 experiences
split_mnist = SplitMNIST(n_experiences=5,return_task_id=True, seed=13)
print('--- Task labels:')
print(split_mnist.task_labels)

loggers = []

# log to text file
loggers.append(TextLogger(open('GDumb_log.txt', 'a')))

# print to stdout
loggers.append(InteractiveLogger())


# loading the model
model = SimpleMLP(num_classes=10)
# defining the optimizer with constant parameters
optimizer = SGD(model.parameters(), lr=0.001, momentum=0.9)
# defining the loss function
criterion = CrossEntropyLoss()
# here the evaluation plugin defined
eval_plugin = EvaluationPlugin(
    accuracy_metrics(experience=True),
    bwt_metrics(experience=True),
    forward_transfer_metrics(experience=True),
    timing_metrics(experience=True,stream=True),
    cpu_usage_metrics(experience=True,stream=True),
    ram_usage_metrics( experience=True, stream=True),
    StreamForwardTransfer(),
    StreamBWT(),

        loggers=loggers,
        collect_all=False,
        strict_checks=False
)
cl_strategy = GDumb(
    model, optimizer,
    CrossEntropyLoss(), train_mb_size=512, train_epochs=10, eval_mb_size=512,
    evaluator=eval_plugin,eval_every=1,
     plugins=[EarlyStoppingPlugin(patience=3, val_stream_name='train')])
# Out:
# --- Task labels:
# [[0], [1], [2], [3], [4]]

# %%
# saving the results of evaluation.
results = []

for experience in split_mnist.train_stream:
    # train returns a dictionary which contains all the metric values
    print("Start of experience::::: ", experience.current_experience)
    print("Current Classes::::: ", experience.classes_in_this_experience)
    cl_strategy.train(experience,eval_streams=[split_mnist.test_stream])
    print('Training completed')

    print('Computing accuracy on the whole test set')
    # test also returns a dictionary which contains all the metric values
    results.append(cl_strategy.eval(experience))
    print('Validation on test sets are completed')
# Out:
# Start of experience:::::  0
# Current Classes:::::  [8, 5]
# -- >> Start of training phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.64it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 89.4233
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5256
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.1897
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.37it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 94.1394
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1136.2656
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5421
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0052
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.78it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 92.2379
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5856
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.2924
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.58it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 94.6261
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1136.2656
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5812
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0028
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.81it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 97.8519
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5149
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0174
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 92.6854
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2656
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.9246
# 100%|██████████| 1/1 [00:00<00:00, 13.27it/s]
# Epoch 0 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.41it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 93.0432
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.6237
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.2299
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.18it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 92.6749
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0021
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1136.2656
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.6476
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0031
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.19it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 95.3867
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1136.2656
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6502
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.2806
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.23it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 94.9232
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4110
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0014
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.14it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 97.6464
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3586
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0144
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.4864
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2656
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0021
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.8680
# 100%|██████████| 1/1 [00:00<00:00, 16.34it/s]
# Epoch 1 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.21it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 97.5262
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3899
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3092
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.11it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 98.5342
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0026
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3553
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0026
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.12it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 97.9422
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1136.2656
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3983
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.2527
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.01it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.1110
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4206
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0009
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.61it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 95.0579
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1136.2656
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3683
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0090
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.3214
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2656
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0026
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0658
# 100%|██████████| 1/1 [00:00<00:00, 17.98it/s]
# Epoch 2 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.68it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 102.4010
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3420
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4078
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.56it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 95.2715
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0036
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3781
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0015
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.83it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.2806
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1136.2656
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4053
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.1998
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.19it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 94.7081
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4120
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.19it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 98.8167
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1136.2656
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3543
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0035
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 97.7307
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2656
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0036
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0264
# 100%|██████████| 1/1 [00:00<00:00, 14.44it/s]
# Epoch 3 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.71it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 99.7020
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3412
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4861
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.92it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 97.6634
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0041
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3688
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0010
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.26it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 93.0176
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1136.2656
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5484
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.1410
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.50it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 93.3259
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5896
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.05it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 92.5805
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5725
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0010
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.0824
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2656
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0041
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.5827
# 100%|██████████| 1/1 [00:00<00:00, 11.00it/s]
# Epoch 4 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.61it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 91.5153
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5245
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5188
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.60it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 94.5570
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5184
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.73it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 90.1746
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5879
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0627
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.87it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 92.0169
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6413
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.05it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 92.4792
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.6597
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 91.9855
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2695
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.1201
# 100%|██████████| 1/1 [00:00<00:00, 12.02it/s]
# Epoch 5 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.98it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 101.7453
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3343
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5268
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.93it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 97.4766
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4002
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.72it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 98.0933
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3672
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0167
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 11.89it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 97.4386
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4210
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.02it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 96.4551
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3942
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.0964
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2695
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0605
# 100%|██████████| 1/1 [00:00<00:00, 19.40it/s]
# Epoch 6 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.45it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 97.3704
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3493
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5305
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.28it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 97.2927
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3907
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.98it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 97.9904
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3981
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0010
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 11.60it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 97.0337
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4330
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.70it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 96.6987
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3725
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.1471
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2695
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0904
# 100%|██████████| 1/1 [00:00<00:00, 16.83it/s]
# Epoch 7 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.20it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 98.7031
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3547
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5338
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.28it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 95.3197
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3885
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.38it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 95.7238
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3866
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.04it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.4113
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4231
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.86it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 99.9969
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3702
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.2718
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2695
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0671
# 100%|██████████| 1/1 [00:00<00:00, 11.72it/s]
# Epoch 8 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.67it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 91.9047
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5224
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5380
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.36it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 93.7051
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5445
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.76it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 91.4570
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5906
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.32it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 91.1328
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6035
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.12it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 92.6439
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5614
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 91.9484
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2695
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.0128
# 100%|██████████| 1/1 [00:00<00:00,  8.89it/s]
# Epoch 9 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.65it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 91.7150
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.7088
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5461
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.86it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 96.8400
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.6816
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  4.49it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 93.8448
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.8846
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 11.55it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 94.1617
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4360
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.56it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 99.5600
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3818
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.1986
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2695
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.2563
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from train stream --
# 100%|██████████| 23/23 [00:02<00:00,  9.35it/s]
# > Eval on experience 0 (Task 0) from train stream ended.
# 	CPUUsage_Exp/eval_phase/train_stream/Task000/Exp000 = 96.8651
# 	MaxRAMUsage_Experience/eval_phase/train_stream/Task000/Exp000 = 1136.2695
# 	Time_Exp/eval_phase/train_stream/Task000/Exp000 = 2.4571
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp000 = 0.5428
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/train_stream/Task000 = 96.3991
# 	MaxRAMUsage_Stream/eval_phase/train_stream/Task000 = 1136.2695
# 	StreamBWT/eval_phase/train_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/train_stream = 0.0000
# 	Time_Stream/eval_phase/train_stream/Task000 = 2.4689
# Validation on test sets are completed
# Start of experience:::::  1
# Current Classes:::::  [4, 6]
# -- >> Start of training phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.53it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 97.8237
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3477
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5461
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.42it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 94.9806
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3898
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.73it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 97.2467
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4115
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.99it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 92.0566
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4564
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.79it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 97.7151
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4095
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.4436
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4062
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.1689
# 100%|██████████| 1/1 [00:00<00:00, 14.11it/s]
# Epoch 0 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.14it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 93.2585
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.3403
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4935
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.2058
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.70it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 96.4867
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5184
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0057
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.97it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 89.4547
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.0103
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5704
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.2821
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.41it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 91.9077
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5985
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0028
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.99it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 90.0509
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5775
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0154
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 91.5544
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4062
# 	StreamBWT/eval_phase/test_stream = -0.3403
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0077
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.9381
# 100%|██████████| 1/1 [00:00<00:00, 10.16it/s]
# Epoch 1 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.73it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.3187
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.3012
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5918
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.2449
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.25it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 92.6164
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.6373
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0088
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.08it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 94.3611
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.0313
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6572
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.2610
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.20it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 93.2097
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6976
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0014
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.84it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 94.2765
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4457
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0139
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.0507
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4062
# 	StreamBWT/eval_phase/test_stream = -0.3012
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0182
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.1899
# 100%|██████████| 1/1 [00:00<00:00, 17.16it/s]
# Epoch 2 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.47it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 94.5913
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.2433
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3491
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3028
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.72it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 98.3039
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3766
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0155
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.46it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.2022
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.0578
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4263
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.2346
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 11.78it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 93.8716
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4264
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0009
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.61it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 96.2542
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4157
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0095
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.7053
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4062
# 	StreamBWT/eval_phase/test_stream = -0.2433
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0315
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.1541
# 100%|██████████| 1/1 [00:00<00:00, 12.71it/s]
# Epoch 3 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.02it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 99.2320
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.1844
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3629
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3617
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.15it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 95.9475
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3962
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0278
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.54it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 92.5389
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.1014
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4216
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.1910
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 11.59it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 96.7648
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4407
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.84it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 96.7322
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4034
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0050
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.4530
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4062
# 	StreamBWT/eval_phase/test_stream = -0.1844
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0533
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.1918
# 100%|██████████| 1/1 [00:00<00:00, 14.74it/s]
# Epoch 4 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.38it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 99.0654
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.1254
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3534
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4207
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.07it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 91.9872
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4024
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0588
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.69it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 97.2824
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.1518
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4113
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.1405
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.81it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 94.8658
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4646
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.32it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 95.1270
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3891
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0015
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.1292
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4062
# 	StreamBWT/eval_phase/test_stream = -0.1254
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0785
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.1865
# 100%|██████████| 1/1 [00:00<00:00, 10.19it/s]
# Epoch 5 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.88it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 89.5941
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0906
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5806
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4555
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.89it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 87.3883
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5836
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.1057
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.05it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 90.4638
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5640
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0872
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.31it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 89.9148
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6898
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.08it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 90.3650
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5646
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 88.3166
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4062
# 	StreamBWT/eval_phase/test_stream = -0.0906
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1052
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.1697
# 100%|██████████| 1/1 [00:00<00:00,  8.29it/s]
# Epoch 6 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.17it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 89.9500
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0691
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4892
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4770
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.69it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 96.3535
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4199
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.1500
# -- Starting eval on experience 2 (Task 2) from test stream --
# ...
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 94.1316
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.1836
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4676
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3051
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.16it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 97.0628
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.0653
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4947
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0070
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.82it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 96.4660
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5082
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0334
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.6775
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4062
# 	StreamBWT/eval_phase/test_stream = -0.2343
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0787
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.5452
# 100%|██████████| 1/1 [00:00<00:00, 12.11it/s]
# Epoch 5 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.16it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 97.5831
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.3317
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4408
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.2144
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.04it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 97.1575
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.3448
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4428
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0134
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.24it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 93.1584
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.1748
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4832
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3139
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.98it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.9716
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.0597
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5003
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0126
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.34it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 97.8477
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4806
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0428
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.4190
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4062
# 	StreamBWT/eval_phase/test_stream = -0.2278
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0787
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.5151
# 100%|██████████| 1/1 [00:00<00:00, 12.26it/s]
# Epoch 6 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.94it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 92.7333
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.3178
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5070
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.2283
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.39it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 80.7167
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.3418
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.6320
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0165
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.19it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 83.5641
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.1690
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6463
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3198
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.46it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 81.8261
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.0532
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6722
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0191
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.72it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 86.0654
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5928
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0548
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 84.8293
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4062
# 	StreamBWT/eval_phase/test_stream = -0.2204
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0787
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.2184
# 100%|██████████| 1/1 [00:00<00:00,  9.01it/s]
# Epoch 7 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.65it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 76.1104
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.3098
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.7097
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.2363
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.14it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 82.7030
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.3335
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.6529
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0247
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.65it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 80.6476
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.1557
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.7069
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3330
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.12it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 82.3084
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.0466
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.7050
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0257
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.32it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 98.2694
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4684
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0692
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 82.9198
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4062
# 	StreamBWT/eval_phase/test_stream = -0.2114
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0787
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.4008
# 100%|██████████| 1/1 [00:00<00:00, 13.17it/s]
# Epoch 8 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.42it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 98.3545
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.3044
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4272
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.2417
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.20it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 93.9772
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.3253
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4897
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0330
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.61it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 97.2077
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.1405
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4631
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3482
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.57it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 92.8993
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.0350
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5276
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0373
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.26it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 96.8878
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4853
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0971
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.5290
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4062
# 	StreamBWT/eval_phase/test_stream = -0.2013
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0787
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.5544
# 100%|██████████| 1/1 [00:00<00:00, 12.99it/s]
# Epoch 9 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.05it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.9378
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.2958
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4438
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.2503
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.68it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 95.0654
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.3119
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4631
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0464
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.27it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 95.0760
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.1273
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4840
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3614
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.36it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 92.5518
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.0219
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1091.4062
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5294
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0504
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.39it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 98.6850
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4767
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.1215
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 93.8085
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4062
# 	StreamBWT/eval_phase/test_stream = -0.1892
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0787
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.5690
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 4 (Task 4) from train stream --
# 100%|██████████| 24/24 [00:03<00:00,  7.59it/s]
# > Eval on experience 4 (Task 4) from train stream ended.
# 	CPUUsage_Exp/eval_phase/train_stream/Task004/Exp004 = 91.1769
# 	MaxRAMUsage_Experience/eval_phase/train_stream/Task004/Exp004 = 1091.4062
# 	Time_Exp/eval_phase/train_stream/Task004/Exp004 = 3.1587
# 	Top1_Acc_Exp/eval_phase/train_stream/Task004/Exp004 = 0.1366
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/train_stream/Task004 = 91.1702
# 	MaxRAMUsage_Stream/eval_phase/train_stream/Task004 = 1091.4062
# 	StreamBWT/eval_phase/train_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/train_stream = -0.0174
# 	Time_Stream/eval_phase/train_stream/Task004 = 3.1695
# Validation on test sets are completed

# %% [markdown]
# # **LwF**

# %%
# loading the benchmark and considering 5 experiences
split_mnist = SplitMNIST(n_experiences=5,return_task_id=True, seed=13)
print('--- Task labels:')
print(split_mnist.task_labels)

loggers = []

# log to text file
loggers.append(TextLogger(open('LwF_log.txt', 'a')))

# print to stdout
loggers.append(InteractiveLogger())


# loading the model
model = SimpleMLP(num_classes=10)
# defining the optimizer with constant parameters
optimizer = SGD(model.parameters(), lr=0.001, momentum=0.9)
# defining the loss function
criterion = CrossEntropyLoss()
# here the evaluation plugin defined
eval_plugin = EvaluationPlugin(
    accuracy_metrics(experience=True),
    bwt_metrics(experience=True),
    forward_transfer_metrics(experience=True),
    timing_metrics(experience=True,stream=True),
    cpu_usage_metrics(experience=True,stream=True),
    ram_usage_metrics( experience=True, stream=True),
    StreamForwardTransfer(),
    StreamBWT(),

        loggers=loggers,
        collect_all=False,
        strict_checks=False
)

cl_strategy = LwF(
    model, optimizer,
    CrossEntropyLoss(),alpha = 0.3, temperature= 0.5, train_mb_size=512, train_epochs=10, eval_mb_size=512,
    evaluator=eval_plugin,eval_every=1,
     plugins=[EarlyStoppingPlugin(patience=3, val_stream_name='train')])
# Out:
# --- Task labels:
# [[0], [1], [2], [3], [4]]

# %%
# saving the results of evaluation.
results = []

for experience in split_mnist.train_stream:
    # train returns a dictionary which contains all the metric values
    print("Start of experience::::: ", experience.current_experience)
    print("Current Classes::::: ", experience.classes_in_this_experience)
    cl_strategy.train(experience,eval_streams=[split_mnist.test_stream])
    print('Training completed')

    print('Computing accuracy on the whole test set')
    # test also returns a dictionary which contains all the metric values
    results.append(cl_strategy.eval(experience))
    print('Validation on test sets are completed')
# Out:
# Start of experience:::::  0
# Current Classes:::::  [8, 5]
# -- >> Start of training phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.58it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 98.7774
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.6077
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.1897
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.39it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 99.0722
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.6260
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0052
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.17it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.6136
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5591
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.2924
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.47it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 99.2955
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4030
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0028
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.78it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 97.1633
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3707
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0174
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 97.0816
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2695
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.7092
# 100%|██████████| 23/23 [00:02<00:00,  9.40it/s]
# Epoch 0 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.62it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 95.7132
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3449
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8767
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.59it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 101.2455
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3459
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.22it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 95.1816
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3890
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.64it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 98.4584
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.3964
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.20it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 100.7009
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3577
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.7784
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2695
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 1.9736
# 100%|██████████| 23/23 [00:02<00:00,  9.57it/s]
# Epoch 1 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.49it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 97.6804
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3482
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9325
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.46it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 96.4337
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3840
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.93it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 97.1106
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5769
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.76it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 91.4567
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6454
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.04it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 93.2458
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5684
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.8640
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2695
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.6568
# 100%|██████████| 23/23 [00:03<00:00,  5.99it/s]
# Epoch 2 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.80it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 97.1066
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5870
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9448
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.25it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 96.8916
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3923
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.85it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 98.6329
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3652
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.99it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 100.4522
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.3885
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.60it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 99.9261
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3805
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 97.0242
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2695
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.2680
# 100%|██████████| 23/23 [00:02<00:00,  9.51it/s]
# Epoch 3 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.54it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 94.5598
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3808
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9518
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.79it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 100.6604
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3677
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.76it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.7420
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3771
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.08it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 96.5009
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4146
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.83it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 98.9611
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4043
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 97.2780
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2695
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0766
# 100%|██████████| 23/23 [00:02<00:00,  9.50it/s]
# Epoch 4 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.55it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 91.2162
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5374
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9566
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.13it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 94.3761
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5619
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.13it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 93.9448
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5643
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.12it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 91.2556
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6139
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.64it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 95.1536
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5255
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 92.0750
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2695
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.9868
# 100%|██████████| 23/23 [00:03<00:00,  7.00it/s]
# Epoch 5 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.11it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 97.0235
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3609
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9625
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.04it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 94.9774
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3582
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.77it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 102.0846
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3724
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.15it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 96.3877
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4152
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.53it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 100.8652
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3769
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.7742
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2695
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0252
# 100%|██████████| 23/23 [00:02<00:00,  9.19it/s]
# Epoch 6 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.02it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.4847
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3734
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9636
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.94it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 95.4259
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3670
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.67it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 95.1225
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4102
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.96it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 97.2271
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4630
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.40it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 95.8482
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3863
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.3033
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2695
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.1511
# 100%|██████████| 23/23 [00:03<00:00,  6.57it/s]
# Epoch 7 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.60it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 94.2029
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.6055
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9636
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.54it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 96.5492
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.6113
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.18it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 95.9883
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6461
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.83it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 96.8298
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5682
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.06it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 95.3266
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3988
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.4620
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2695
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.9754
# 100%|██████████| 23/23 [00:02<00:00,  9.16it/s]
# Epoch 8 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.17it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 95.7651
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3551
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9646
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.59it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 96.9593
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3818
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.44it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.5625
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3870
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.18it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 96.3279
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4155
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.01it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 98.4002
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3659
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.3200
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2695
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0350
# 100%|██████████| 23/23 [00:02<00:00,  9.54it/s]
# Epoch 9 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.27it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.0024
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3544
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9646
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.03it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 98.2146
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3667
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.82it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 97.7754
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4094
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.19it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 97.6609
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5428
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.14it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 90.9880
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5607
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.4268
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2695
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.3829
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from train stream --
# 100%|██████████| 23/23 [00:03<00:00,  7.13it/s]
# > Eval on experience 0 (Task 0) from train stream ended.
# 	CPUUsage_Exp/eval_phase/train_stream/Task000/Exp000 = 92.2327
# 	MaxRAMUsage_Experience/eval_phase/train_stream/Task000/Exp000 = 1136.2695
# 	Time_Exp/eval_phase/train_stream/Task000/Exp000 = 3.2309
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp000 = 0.9597
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/train_stream/Task000 = 92.1270
# 	MaxRAMUsage_Stream/eval_phase/train_stream/Task000 = 1136.2695
# 	StreamBWT/eval_phase/train_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/train_stream = 0.0000
# 	Time_Stream/eval_phase/train_stream/Task000 = 3.2360
# Validation on test sets are completed
# Start of experience:::::  1
# Current Classes:::::  [4, 6]
# -- >> Start of training phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.59it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.8331
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3718
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9646
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.80it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 97.5026
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4104
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.91it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 94.3213
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4030
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.96it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 96.4198
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4565
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.42it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 98.5351
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3859
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.8189
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2695
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.1715
# 100%|██████████| 23/23 [00:02<00:00,  8.00it/s]
# Epoch 0 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.26it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 95.7655
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9544
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3551
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0102
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.53it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 97.4470
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3799
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9639
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.62it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.3926
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4153
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.06it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.6116
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4185
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.73it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 99.1710
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3733
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.9872
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2695
# 	StreamBWT/eval_phase/test_stream = -0.9544
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0836
# 100%|██████████| 23/23 [00:03<00:00,  5.81it/s]
# Epoch 1 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.95it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 94.3048
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4986
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.90it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 88.3172
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5777
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9773
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.70it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 91.3175
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.7011
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  6.83it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 90.3025
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.7312
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.99it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 89.9202
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.6676
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 90.2890
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2695
# 	StreamBWT/eval_phase/test_stream = -0.9646
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.3787
# 100%|██████████| 23/23 [00:02<00:00,  8.19it/s]
# Epoch 2 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.16it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 97.8923
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4394
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.65it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 98.0990
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3773
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9809
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.16it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.1137
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3955
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 11.61it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 97.8395
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4294
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.66it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 100.9213
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3767
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 97.3985
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2695
# 	StreamBWT/eval_phase/test_stream = -0.9646
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.1767
# 100%|██████████| 23/23 [00:02<00:00,  8.25it/s]
# Epoch 3 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.84it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.8293
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3723
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.41it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 95.3077
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3779
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9820
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.60it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 90.1339
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5995
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.95it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 87.6480
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1136.2695
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6277
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.55it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 87.6002
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.6050
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 90.3111
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1136.2695
# 	StreamBWT/eval_phase/test_stream = -0.9646
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.7460
# 100%|██████████| 23/23 [00:04<00:00,  4.82it/s]
# Epoch 4 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.26it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 90.3355
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4874
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.32it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 95.6333
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3904
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9830
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.16it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.6426
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.4141
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4348
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 11.60it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 97.8800
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4293
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.48it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 93.5727
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.4141
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3850
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 93.6050
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4141
# 	StreamBWT/eval_phase/test_stream = -0.9646
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.2969
# 100%|██████████| 23/23 [00:02<00:00,  8.13it/s]
# Epoch 5 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.08it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.9587
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3612
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.27it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 97.0969
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3915
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9845
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.57it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 95.1336
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.4141
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4205
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 11.26it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 99.5320
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4422
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.32it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 95.3201
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.4141
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3884
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.6579
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4141
# 	StreamBWT/eval_phase/test_stream = -0.9646
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.1536
# 100%|██████████| 23/23 [00:03<00:00,  6.53it/s]
# Epoch 6 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.68it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 91.9986
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5219
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.33it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 97.1436
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1091.4141
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5459
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9856
# ...
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 92.2108
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.9716
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.4141
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4991
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.88it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.7725
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.6758
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1091.4141
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5117
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.3190
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.99it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 94.0990
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4997
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9930
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 93.8798
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4141
# 	StreamBWT/eval_phase/test_stream = -0.8995
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.5779
# 100%|██████████| 24/24 [00:03<00:00,  7.10it/s]
# Epoch 5 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.49it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 76.2497
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.6209
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.32it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 80.5355
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.9861
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1091.4141
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.6335
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.45it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 84.1620
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.9716
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6179
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.70it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 82.9565
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.7076
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6547
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.2873
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.38it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 81.2876
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1091.4141
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.6276
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9950
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 81.3324
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4141
# 	StreamBWT/eval_phase/test_stream = -0.9075
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.3442
# 100%|██████████| 24/24 [00:04<00:00,  5.30it/s]
# Epoch 6 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.86it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 94.6506
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4545
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.54it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 93.6753
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.9861
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4698
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.21it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 97.1328
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.9716
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4841
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.35it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.4842
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.7416
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1091.4141
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5342
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.2533
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.40it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 96.2018
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4783
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9950
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.7839
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4141
# 	StreamBWT/eval_phase/test_stream = -0.9160
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.5959
# 100%|██████████| 24/24 [00:03<00:00,  7.46it/s]
# Epoch 7 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.27it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 94.0898
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4360
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.77it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 95.5283
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.9861
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4608
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.22it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 93.1881
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.9716
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.4141
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4831
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.68it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 94.4520
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.7691
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1091.4141
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5296
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.2257
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.74it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 96.2956
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4571
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9945
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 93.9088
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4141
# 	StreamBWT/eval_phase/test_stream = -0.9229
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.5343
# 100%|██████████| 24/24 [00:04<00:00,  5.71it/s]
# Epoch 8 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.35it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 74.7588
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.7495
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.44it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 79.0431
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.9861
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1091.4141
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.7338
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.51it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 79.8097
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.9716
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.4141
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.7269
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.68it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 87.4021
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.7892
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1091.4141
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6524
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.2057
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.12it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 95.2468
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4937
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9945
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 82.2754
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4141
# 	StreamBWT/eval_phase/test_stream = -0.9279
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.5366
# 100%|██████████| 24/24 [00:03<00:00,  7.29it/s]
# Epoch 9 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.01it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 98.2632
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4481
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.63it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 95.0344
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.9861
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4632
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.23it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 97.4800
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.9716
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1091.4141
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4823
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.57it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 93.6006
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.8041
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1091.4141
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5237
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.1908
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.25it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 96.6280
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4866
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9945
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.6770
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1091.4141
# 	StreamBWT/eval_phase/test_stream = -0.9316
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.5607
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 4 (Task 4) from train stream --
# 100%|██████████| 24/24 [00:02<00:00,  8.39it/s]
# > Eval on experience 4 (Task 4) from train stream ended.
# 	CPUUsage_Exp/eval_phase/train_stream/Task004/Exp004 = 94.5369
# 	MaxRAMUsage_Experience/eval_phase/train_stream/Task004/Exp004 = 1091.4141
# 	Time_Exp/eval_phase/train_stream/Task004/Exp004 = 2.8559
# 	Top1_Acc_Exp/eval_phase/train_stream/Task004/Exp004 = 0.9951
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/train_stream/Task004 = 94.7144
# 	MaxRAMUsage_Stream/eval_phase/train_stream/Task004 = 1091.4141
# 	StreamBWT/eval_phase/train_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/train_stream = -0.0174
# 	Time_Stream/eval_phase/train_stream/Task004 = 2.8614
# Validation on test sets are completed

# %% [markdown]
# # **EWC**

# %%
# loading the benchmark and considering 5 experiences
split_mnist = SplitMNIST(n_experiences=5,return_task_id=True, seed=13)
print('--- Task labels:')
print(split_mnist.task_labels)

loggers = []

# log to text file
loggers.append(TextLogger(open('EWC_log.txt', 'a')))

# print to stdout
loggers.append(InteractiveLogger())


# loading the model
model = SimpleMLP(num_classes=10)
# defining the optimizer with constant parameters
optimizer = SGD(model.parameters(), lr=0.001, momentum=0.9)
# defining the loss function
criterion = CrossEntropyLoss()
# here the evaluation plugin defined
eval_plugin = EvaluationPlugin(
    accuracy_metrics(experience=True),
    bwt_metrics(experience=True),
    forward_transfer_metrics(experience=True),
    timing_metrics(experience=True,stream=True),
    cpu_usage_metrics(experience=True,stream=True),
    ram_usage_metrics( experience=True, stream=True),
    StreamForwardTransfer(),
    StreamBWT(),

        loggers=loggers,
        collect_all=False,
        strict_checks=False
)

cl_strategy = EWC(
    model, optimizer,
    CrossEntropyLoss(),ewc_lambda=0.4, train_mb_size=512, train_epochs=10, eval_mb_size=512,
    evaluator=eval_plugin,eval_every=1,
     plugins=[EarlyStoppingPlugin(patience=3, val_stream_name='train')])
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /root/.avalanche/data/mnist/TensorMNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 308114300.44it/s]
# Extracting /root/.avalanche/data/mnist/TensorMNIST/raw/train-images-idx3-ubyte.gz to /root/.avalanche/data/mnist/TensorMNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /root/.avalanche/data/mnist/TensorMNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 75333142.93it/s]
# Extracting /root/.avalanche/data/mnist/TensorMNIST/raw/train-labels-idx1-ubyte.gz to /root/.avalanche/data/mnist/TensorMNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /root/.avalanche/data/mnist/TensorMNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 117010259.65it/s]
# Extracting /root/.avalanche/data/mnist/TensorMNIST/raw/t10k-images-idx3-ubyte.gz to /root/.avalanche/data/mnist/TensorMNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /root/.avalanche/data/mnist/TensorMNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 11810619.20it/s]
# Extracting /root/.avalanche/data/mnist/TensorMNIST/raw/t10k-labels-idx1-ubyte.gz to /root/.avalanche/data/mnist/TensorMNIST/raw
#
# --- Task labels:
# [[0], [1], [2], [3], [4]]

# %%
# saving the results of evaluation.
results = []

for experience in split_mnist.train_stream:
    # train returns a dictionary which contains all the metric values
    print("Start of experience::::: ", experience.current_experience)
    print("Current Classes::::: ", experience.classes_in_this_experience)
    cl_strategy.train(experience,eval_streams=[split_mnist.test_stream])
    print('Training completed')

    print('Computing accuracy on the whole test set')
    # test also returns a dictionary which contains all the metric values
    results.append(cl_strategy.eval(experience))
    print('Validation on test sets are completed')
# Out:
# Start of experience:::::  0
# Current Classes:::::  [8, 5]
# -- >> Start of training phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.92it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 82.5401
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4485
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.1897
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.40it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 98.9720
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3542
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0052
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.06it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.4753
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 940.5352
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4044
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.2924
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.43it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 97.2674
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4010
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0028
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.63it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 97.5648
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 940.5352
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3794
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0174
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 93.4581
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 940.5352
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.1401
# 100%|██████████| 23/23 [00:05<00:00,  4.10it/s]
# Epoch 0 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:01<00:00,  2.86it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 37.1626
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 958.5391
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 1.3989
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8767
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:01<00:00,  2.63it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 35.8087
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 958.5391
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 1.5310
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:01<00:00,  2.99it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 49.0562
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 958.5391
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 1.3667
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:01<00:00,  3.62it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 50.7830
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 958.5391
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 1.3789
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.34it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 93.6531
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3633
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 45.6573
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 958.5391
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 6.4156
# 100%|██████████| 23/23 [00:02<00:00,  9.79it/s]
# Epoch 1 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.52it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 95.0634
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3472
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9325
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.92it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 98.0014
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3675
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.84it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 95.7890
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 958.5391
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3654
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.79it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 98.6406
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.3955
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.50it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 97.3884
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3800
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 97.1328
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 958.5391
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 1.9870
# 100%|██████████| 23/23 [00:02<00:00,  9.90it/s]
# Epoch 2 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.99it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.0774
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3332
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9448
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.05it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 99.8092
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3634
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.49it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.2264
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 961.7383
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3846
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.00it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 89.1243
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6286
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.81it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 97.1553
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 961.7383
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5147
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.9095
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 961.7383
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.3704
# 100%|██████████| 23/23 [00:03<00:00,  6.43it/s]
# Epoch 3 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.72it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.9982
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5980
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9518
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.32it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 90.9980
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 961.7383
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5497
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.41it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 95.4531
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3914
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 11.83it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 98.9898
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 961.7383
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4245
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.21it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 97.0921
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3916
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.3889
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 961.7383
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.5110
# 100%|██████████| 23/23 [00:02<00:00,  9.77it/s]
# Epoch 4 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.83it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.1288
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3434
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9566
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.49it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 98.6073
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3450
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.23it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 98.9469
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 961.7383
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3943
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.42it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 96.0355
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4105
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.86it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 98.8411
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 961.7383
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3643
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.5226
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 961.7383
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 1.9995
# 100%|██████████| 23/23 [00:02<00:00,  8.62it/s]
# Epoch 5 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.94it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 93.5691
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5148
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9625
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.25it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 99.1592
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 961.7461
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4841
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.58it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 90.5037
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6078
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.80it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.8956
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 961.7461
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5738
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.62it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 95.4383
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5239
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 93.1475
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 961.7461
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.8876
# 100%|██████████| 23/23 [00:03<00:00,  6.44it/s]
# Epoch 6 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.81it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 98.0628
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3366
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9636
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.71it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 99.0679
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3736
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.89it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 94.8759
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 961.7461
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3691
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 11.83it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 96.4056
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4253
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.85it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 96.9561
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 961.7461
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4024
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.0329
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 961.7461
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0512
# 100%|██████████| 23/23 [00:02<00:00,  9.70it/s]
# Epoch 7 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.45it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 92.4278
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3572
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9636
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.59it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 59.3910
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 961.7461
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.7069
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.61it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 94.3327
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3818
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.52it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 90.6036
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 961.7461
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5851
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.34it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 80.4509
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5471
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 80.8069
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 961.7461
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.7719
# 100%|██████████| 23/23 [00:03<00:00,  6.90it/s]
# Epoch 8 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.15it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 93.3239
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4931
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9646
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.78it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 95.2826
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 961.7461
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5146
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.42it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.9646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5366
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.63it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 92.7951
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 961.7461
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6577
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.38it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 95.9859
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.6253
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.8104
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 961.7461
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.9741
# 100%|██████████| 23/23 [00:02<00:00,  7.78it/s]
# Epoch 9 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.28it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 94.7309
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3907
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9646
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.83it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 97.4017
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3697
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.58it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 95.4345
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 961.7461
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3774
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 11.70it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.5068
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4295
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.59it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 98.2829
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 961.7461
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3765
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.9227
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 961.7461
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0850
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from train stream --
# 100%|██████████| 23/23 [00:02<00:00, 11.24it/s]
# > Eval on experience 0 (Task 0) from train stream ended.
# 	CPUUsage_Exp/eval_phase/train_stream/Task000/Exp000 = 98.0291
# 	MaxRAMUsage_Experience/eval_phase/train_stream/Task000/Exp000 = 962.5312
# 	Time_Exp/eval_phase/train_stream/Task000/Exp000 = 2.0503
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp000 = 0.9597
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/train_stream/Task000 = 97.5321
# 	MaxRAMUsage_Stream/eval_phase/train_stream/Task000 = 962.5312
# 	StreamBWT/eval_phase/train_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/train_stream = 0.0000
# 	Time_Stream/eval_phase/train_stream/Task000 = 2.0604
# Validation on test sets are completed
# Start of experience:::::  1
# Current Classes:::::  [4, 6]
# -- >> Start of training phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 12.00it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 98.6313
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3347
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9646
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.94it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 93.5717
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5025
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.59it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 87.2781
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 962.5312
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6076
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.31it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 93.0324
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 962.5312
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6022
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.08it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 91.5842
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5680
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 91.7377
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 962.5312
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.7920
# 100%|██████████| 23/23 [00:03<00:00,  5.95it/s]
# Epoch 0 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.86it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.2731
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9389
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5818
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0257
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.72it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 88.6537
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 971.1445
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4626
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9644
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.08it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 94.2741
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3959
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 11.32it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 94.7304
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 971.1445
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4463
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.45it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 97.9702
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3779
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.4401
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 971.1445
# 	StreamBWT/eval_phase/test_stream = -0.9389
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.4142
# 100%|██████████| 23/23 [00:02<00:00,  8.55it/s]
# Epoch 1 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.92it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 95.7622
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3656
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.44it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 97.7187
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4300
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9778
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.98it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 73.0272
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 972.6758
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6712
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.71it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 81.6304
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 972.6758
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5759
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  4.37it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 65.7589
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 972.6758
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9126
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 79.3637
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 972.6758
# 	StreamBWT/eval_phase/test_stream = -0.9646
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.0876
# 100%|██████████| 23/23 [00:05<00:00,  4.24it/s]
# Epoch 2 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.62it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 91.0605
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5273
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.20it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 87.2961
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 973.1836
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.6417
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9809
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.30it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 91.1285
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6367
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  6.71it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 88.4080
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 973.1836
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.7466
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.82it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 91.4611
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 973.1836
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5905
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 89.4598
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 973.1836
# 	StreamBWT/eval_phase/test_stream = -0.9646
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.3091
# 100%|██████████| 23/23 [00:02<00:00,  7.99it/s]
# Epoch 3 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.83it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 63.2395
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5853
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  4.61it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 78.3066
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 970.3477
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.8685
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9820
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.02it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 98.5059
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3962
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 11.39it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.4164
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 970.3477
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4404
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.90it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 96.4614
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4045
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 83.7055
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 970.3477
# 	StreamBWT/eval_phase/test_stream = -0.9646
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.8673
# 100%|██████████| 23/23 [00:02<00:00,  8.53it/s]
# Epoch 4 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.25it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 98.2450
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3563
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.81it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 94.8343
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4536
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9830
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.53it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 91.6177
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 969.8164
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6114
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.92it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 96.1600
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 969.8164
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5617
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.52it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 94.8178
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5274
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 93.6909
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 969.8164
# 	StreamBWT/eval_phase/test_stream = -0.9646
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.6683
# 100%|██████████| 23/23 [00:03<00:00,  5.93it/s]
# Epoch 5 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.30it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 88.2607
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.6346
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.53it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 87.9063
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 970.3320
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.6145
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9845
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.06it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 97.7580
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3991
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.94it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 94.3507
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 970.3320
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4558
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.18it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 96.9678
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4333
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 91.1580
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 970.3320
# 	StreamBWT/eval_phase/test_stream = -0.9646
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.6985
# 100%|██████████| 23/23 [00:02<00:00,  8.61it/s]
# Epoch 6 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.81it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.0577
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3748
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.71it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 98.9971
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3738
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9851
# -- Starting eval on experience 2 (Task 2) from test stream --
# ...
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.9706
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1012.4062
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.8102
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:01<00:00,  3.51it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 46.8868
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.7001
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1012.4062
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 1.4075
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.2948
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:01<00:00,  2.87it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 46.0646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1012.4062
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 1.3896
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9915
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 60.0069
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1012.4062
# 	StreamBWT/eval_phase/test_stream = -0.9054
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 4.9664
# 100%|██████████| 24/24 [00:03<00:00,  7.32it/s]
# Epoch 5 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.41it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 95.3074
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4303
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.92it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 95.3080
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.9861
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4513
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.37it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 94.3551
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.9706
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1012.4062
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4771
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.18it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 96.4676
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.7355
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4876
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.2593
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.18it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 92.8413
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4849
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9930
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.7277
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1012.4062
# 	StreamBWT/eval_phase/test_stream = -0.9142
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.4915
# 100%|██████████| 24/24 [00:03<00:00,  6.46it/s]
# Epoch 6 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.18it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 92.1692
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4884
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.19it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 88.4267
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.9861
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1012.4062
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5543
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.81it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 95.9002
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.9706
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5111
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.20it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 88.6897
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.7649
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1012.4062
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6091
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.2299
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.97it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 85.9442
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5703
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9940
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 89.5550
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1012.4062
# 	StreamBWT/eval_phase/test_stream = -0.9216
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.9149
# 100%|██████████| 24/24 [00:04<00:00,  5.27it/s]
# Epoch 7 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.44it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 82.3146
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.6198
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.97it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 82.7302
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.9861
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1012.4062
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5802
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.81it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 94.2336
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.9706
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4564
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.62it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 92.1263
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.7859
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1012.4062
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5211
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.2090
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.53it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 100.2388
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4692
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9940
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 89.0883
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1012.4062
# 	StreamBWT/eval_phase/test_stream = -0.9268
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.8397
# 100%|██████████| 24/24 [00:03<00:00,  7.25it/s]
# Epoch 8 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.69it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.5895
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4142
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.67it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 95.6923
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.9861
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4600
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.47it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 99.8203
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.9706
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1012.4062
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4710
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.31it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 93.0494
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.8036
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1012.4062
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5377
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.1912
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.40it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 94.4135
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4767
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9940
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.6835
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1012.4062
# 	StreamBWT/eval_phase/test_stream = -0.9312
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.5187
# 100%|██████████| 24/24 [00:06<00:00,  3.87it/s]
# Epoch 9 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.20it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 79.0502
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9646
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.6455
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.04it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 74.0129
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.9861
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1012.4062
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.7835
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  4.71it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 67.2882
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.9706
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1012.4062
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.8476
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:01<00:00,  4.76it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 58.6006
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.8148
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1012.4062
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 1.0586
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.1800
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.33it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 73.4815
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1012.4062
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.7486
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9935
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 68.6900
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1012.4062
# 	StreamBWT/eval_phase/test_stream = -0.9340
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 4.3389
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 4 (Task 4) from train stream --
# 100%|██████████| 24/24 [00:02<00:00,  8.90it/s]
# > Eval on experience 4 (Task 4) from train stream ended.
# 	CPUUsage_Exp/eval_phase/train_stream/Task004/Exp004 = 94.8472
# 	MaxRAMUsage_Experience/eval_phase/train_stream/Task004/Exp004 = 1012.4062
# 	Time_Exp/eval_phase/train_stream/Task004/Exp004 = 2.6991
# 	Top1_Acc_Exp/eval_phase/train_stream/Task004/Exp004 = 0.9947
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/train_stream/Task004 = 94.6977
# 	MaxRAMUsage_Stream/eval_phase/train_stream/Task004 = 1012.4062
# 	StreamBWT/eval_phase/train_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/train_stream = -0.0174
# 	Time_Stream/eval_phase/train_stream/Task004 = 2.7046
# Validation on test sets are completed

# %% [markdown]
# # **CWRStar**

# %%
# loading the benchmark and considering 5 experiences
split_mnist = SplitMNIST(n_experiences=5,return_task_id=True, seed=13)
print('--- Task labels:')
print(split_mnist.task_labels)

loggers = []

# log to text file
loggers.append(TextLogger(open('CWRstar_log.txt', 'a')))

# print to stdout
loggers.append(InteractiveLogger())


# loading the model
model = SimpleMLP(num_classes=10)
# defining the optimizer with constant parameters
optimizer = SGD(model.parameters(), lr=0.001, momentum=0.9)
# defining the loss function
criterion = CrossEntropyLoss()
# here the evaluation plugin defined
eval_plugin = EvaluationPlugin(
    accuracy_metrics(experience=True),
    bwt_metrics(experience=True),
    forward_transfer_metrics(experience=True),
    timing_metrics(experience=True,stream=True),
    cpu_usage_metrics(experience=True,stream=True),
    ram_usage_metrics( experience=True, stream=True),
    StreamForwardTransfer(),
    StreamBWT(),

        loggers=loggers,
        collect_all=False,
        strict_checks=False
)

cl_strategy = CWRStar(
    model, optimizer,
    CrossEntropyLoss(),cwr_layer_name=None, train_mb_size=512, train_epochs=10, eval_mb_size=512,
    evaluator=eval_plugin,eval_every=1,
     plugins=[EarlyStoppingPlugin(patience=3, val_stream_name='train')])
# Out:
# --- Task labels:
# [[0], [1], [2], [3], [4]]

# %%
# saving the results of evaluation.
results = []

for experience in split_mnist.train_stream:
    # train returns a dictionary which contains all the metric values
    print("Start of experience::::: ", experience.current_experience)
    print("Current Classes::::: ", experience.classes_in_this_experience)
    cl_strategy.train(experience,eval_streams=[split_mnist.test_stream])
    print('Training completed')

    print('Computing accuracy on the whole test set')
    # test also returns a dictionary which contains all the metric values
    results.append(cl_strategy.eval(experience))
    print('Validation on test sets are completed')
# Out:
# Start of experience:::::  0
# Current Classes:::::  [8, 5]
# -- >> Start of training phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.73it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.6042
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3416
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.1897
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.06it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 98.7539
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3979
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0052
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.26it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.5069
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1149.3281
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3941
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.2924
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.86it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 97.0406
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.3917
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0028
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.67it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 99.9083
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1149.3281
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3806
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0174
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 98.1008
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.3281
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0285
# 100%|██████████| 23/23 [00:03<00:00,  6.31it/s]
# Epoch 0 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.53it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.1042
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.6139
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5702
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.48it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 91.5548
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1149.3281
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.7320
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.77it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 95.9028
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4589
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.59it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 100.1569
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1149.3281
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.3996
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.47it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 95.9160
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3859
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.0483
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.3281
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.7459
# 100%|██████████| 23/23 [00:02<00:00,  9.59it/s]
# Epoch 1 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.33it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 97.0962
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3915
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9191
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.25it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 95.7555
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3553
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.41it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.5251
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1149.3281
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3834
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.21it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 96.6888
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4138
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.00it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 99.3542
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1149.3281
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3625
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.9767
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.3281
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0315
# 100%|██████████| 23/23 [00:02<00:00,  9.61it/s]
# Epoch 2 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.95it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 98.8473
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3340
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9378
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.55it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 98.0005
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3776
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.19it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 95.4020
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1149.3281
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5556
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.44it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 92.3944
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5955
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.39it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 100.7724
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5460
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.4281
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.3281
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.5616
# 100%|██████████| 23/23 [00:03<00:00,  6.70it/s]
# Epoch 3 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.76it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 97.1661
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3398
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9453
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.92it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 96.4189
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3633
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.68it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 98.9086
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1149.3281
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3743
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 11.89it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 98.4793
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4266
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.68it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 97.6951
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1149.3281
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3789
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.8139
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.3281
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0143
# 100%|██████████| 23/23 [00:02<00:00,  9.63it/s]
# Epoch 4 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.62it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 94.7349
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3801
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9539
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.91it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 95.0184
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3685
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.50it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.4441
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1149.3281
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3838
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.19it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 96.7517
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4137
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.87it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 98.0715
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1149.3281
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3673
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.5999
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.3281
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0502
# 100%|██████████| 23/23 [00:03<00:00,  7.26it/s]
# Epoch 5 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.78it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 91.7902
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5231
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9555
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.42it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 93.7013
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1149.3281
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5340
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.19it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.6220
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5590
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.94it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 93.4250
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1149.3281
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6316
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.76it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 95.2802
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1149.3281
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.6928
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 93.4467
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.3281
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.1032
# 100%|██████████| 23/23 [00:02<00:00,  9.32it/s]
# Epoch 6 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.11it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 94.3969
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3603
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9566
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.24it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 97.5780
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3591
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.45it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 99.4985
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1149.3281
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3820
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.17it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 96.8331
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4134
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.28it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 100.5544
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1149.3281
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3584
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.8662
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.3281
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0053
# 100%|██████████| 23/23 [00:02<00:00,  9.50it/s]
# Epoch 7 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.42it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 95.6912
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3868
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9593
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.28it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 98.9233
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3542
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.91it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 94.3190
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1149.3281
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4031
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.27it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 94.0916
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6059
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.44it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 93.7021
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1149.3281
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5337
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.4711
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.3281
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.4195
# 100%|██████████| 23/23 [00:04<00:00,  5.26it/s]
# Epoch 8 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.74it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 90.6748
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4634
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9625
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.68it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 100.8800
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3768
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.85it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 94.7689
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1104.6094
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4010
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 11.44it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 94.3939
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4451
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.46it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 98.5285
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1104.6094
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4774
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.3064
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1104.6094
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.3189
# 100%|██████████| 23/23 [00:02<00:00,  9.55it/s]
# Epoch 9 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.05it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 97.3403
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3598
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9636
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.31it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 95.4420
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3881
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.13it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.3898
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1104.6094
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3945
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 12.09it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 98.6497
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4157
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.57it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 95.1287
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1104.6094
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.3786
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.3261
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1104.6094
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.0764
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from train stream --
# 100%|██████████| 23/23 [00:02<00:00,  9.32it/s]
# > Eval on experience 0 (Task 0) from train stream ended.
# 	CPUUsage_Exp/eval_phase/train_stream/Task000/Exp000 = 96.4544
# 	MaxRAMUsage_Experience/eval_phase/train_stream/Task000/Exp000 = 1104.6094
# 	Time_Exp/eval_phase/train_stream/Task000/Exp000 = 2.4677
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp000 = 0.9553
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/train_stream/Task000 = 96.3966
# 	MaxRAMUsage_Stream/eval_phase/train_stream/Task000 = 1104.6094
# 	StreamBWT/eval_phase/train_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/train_stream = 0.0000
# 	Time_Stream/eval_phase/train_stream/Task000 = 2.4793
# Validation on test sets are completed
# Start of experience:::::  1
# Current Classes:::::  [4, 6]
# -- >> Start of training phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.30it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.4542
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5393
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.9636
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.24it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 92.7072
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = -0.0052
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1104.6094
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5504
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.02it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 94.5331
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5714
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.15it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 90.6891
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1104.6094
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6176
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.57it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 89.0026
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1104.6094
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.6070
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 91.7181
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1104.6094
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0052
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.0747
# 100%|██████████| 23/23 [00:02<00:00,  8.43it/s]
# Epoch 0 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.39it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 98.0799
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9636
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4285
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.79it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 96.7971
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3722
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9541
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.42it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 93.6889
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1104.6094
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4271
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 11.98it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 100.6155
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4212
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.54it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 95.7749
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1104.6094
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4179
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.9725
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1104.6094
# 	StreamBWT/eval_phase/test_stream = -0.9636
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.2088
# 100%|██████████| 23/23 [00:02<00:00,  9.70it/s]
# Epoch 1 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.39it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 100.1870
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9636
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3494
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.78it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 95.8086
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4073
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9619
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.17it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 99.1361
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1104.6094
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3935
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.99it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 97.1984
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4530
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.16it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 92.9009
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1104.6094
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5600
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.4143
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1104.6094
# 	StreamBWT/eval_phase/test_stream = -0.9636
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.3161
# 100%|██████████| 23/23 [00:03<00:00,  6.15it/s]
# Epoch 2 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.42it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 95.6406
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9636
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3870
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.25it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 96.9910
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3919
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9686
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.45it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.8013
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1104.6094
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4238
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 11.95it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 97.8212
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4193
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.54it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 94.8897
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1104.6094
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4216
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.1290
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1104.6094
# 	StreamBWT/eval_phase/test_stream = -0.9636
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.1949
# 100%|██████████| 23/23 [00:02<00:00,  9.79it/s]
# Epoch 3 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.41it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 99.0157
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9636
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3841
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.59it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 93.0501
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4193
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9701
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.78it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 95.5093
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1104.6094
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4086
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.97it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 97.6569
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4609
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.88it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 95.5453
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1104.6094
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4084
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.8893
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1104.6094
# 	StreamBWT/eval_phase/test_stream = -0.9636
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.2345
# 100%|██████████| 23/23 [00:02<00:00,  8.17it/s]
# Epoch 4 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.37it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 89.4336
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9636
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5368
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.35it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 88.5071
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1104.6094
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5426
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9742
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.86it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 89.2931
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5824
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.58it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 94.2502
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1104.6094
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5837
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.79it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 87.8652
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1104.6094
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5806
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 89.4856
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1104.6094
# 	StreamBWT/eval_phase/test_stream = -0.9636
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.0060
# 100%|██████████| 23/23 [00:02<00:00,  7.77it/s]
# Epoch 5 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.92it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 92.7469
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9636
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3678
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.04it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 92.0749
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4022
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9753
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.37it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 98.6305
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = -0.2924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1104.6094
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3854
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 11.54it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 91.7931
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4358
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.62it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 97.1996
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1104.6094
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4219
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.6933
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1104.6094
# 	StreamBWT/eval_phase/test_stream = -0.9636
# 	StreamForwardTransfer/eval_phase/test_stream = -0.1488
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.1652
# 100%|██████████| 23/23 [00:02<00:00,  9.63it/s]
# Epoch 6 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.78it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 94.2567
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9636
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3716
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.24it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 95.5785
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3980
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9773
# ...
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.5833
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6439
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  6.85it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 79.7580
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.8899
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1104.6133
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.7274
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.48it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 78.1289
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1104.6133
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.7317
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9890
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 82.8888
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1104.6133
# 	StreamBWT/eval_phase/test_stream = -0.8232
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.3780
# 100%|██████████| 24/24 [00:03<00:00,  7.83it/s]
# Epoch 5 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.30it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 97.0123
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9636
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4331
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.91it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 97.5972
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.8562
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4511
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.45it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 95.0834
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.5833
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1104.6133
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4735
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.68it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 96.5986
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.8899
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1104.6133
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5179
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.46it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 95.7544
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4700
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9900
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.0289
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1104.6133
# 	StreamBWT/eval_phase/test_stream = -0.8232
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.5095
# 100%|██████████| 24/24 [00:02<00:00,  8.60it/s]
# Epoch 6 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.47it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 98.5313
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9636
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4264
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.52it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 96.1581
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.8562
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4681
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.89it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 79.6910
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.5833
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1104.6133
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6775
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.20it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 80.3560
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.8899
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1104.6133
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6970
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.80it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 76.9034
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1104.6133
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.6893
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9920
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 83.5200
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1104.6172
# 	StreamBWT/eval_phase/test_stream = -0.8232
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.1388
# 100%|██████████| 24/24 [00:03<00:00,  6.42it/s]
# Epoch 7 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.05it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.8664
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9636
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4440
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.57it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 94.4134
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.8562
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1104.6172
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5299
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.46it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 92.6931
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.5833
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4780
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.63it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.9177
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.8899
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1104.6172
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5216
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.00it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 98.9487
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.7987
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9920
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.9420
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1104.6172
# 	StreamBWT/eval_phase/test_stream = -0.8232
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.9292
# 100%|██████████| 24/24 [00:02<00:00,  8.75it/s]
# Epoch 8 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.99it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 93.9142
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9636
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5007
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.12it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 96.0095
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.8562
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1104.6172
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5001
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.22it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.4115
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.5833
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4876
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.98it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.3533
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.8899
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1104.6172
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5141
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.81it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 89.0095
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5845
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9920
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 93.5910
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1104.6172
# 	StreamBWT/eval_phase/test_stream = -0.8232
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.7567
# 100%|██████████| 24/24 [00:03<00:00,  6.44it/s]
# Epoch 9 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.10it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 83.1256
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.9636
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5655
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.29it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 87.8773
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.8562
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1104.6172
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5489
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.18it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 81.3677
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.5833
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6516
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  6.89it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 79.7063
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.8899
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1104.6172
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.7280
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.92it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 81.3841
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1104.6172
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.6758
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9920
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 82.0730
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1104.6172
# 	StreamBWT/eval_phase/test_stream = -0.8232
# 	StreamForwardTransfer/eval_phase/test_stream = -0.0794
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.3628
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 4 (Task 4) from train stream --
# 100%|██████████| 24/24 [00:03<00:00,  7.90it/s]
# > Eval on experience 4 (Task 4) from train stream ended.
# 	CPUUsage_Exp/eval_phase/train_stream/Task004/Exp004 = 91.4627
# 	MaxRAMUsage_Experience/eval_phase/train_stream/Task004/Exp004 = 1104.6172
# 	Time_Exp/eval_phase/train_stream/Task004/Exp004 = 3.0397
# 	Top1_Acc_Exp/eval_phase/train_stream/Task004/Exp004 = 0.6056
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/train_stream/Task004 = 91.5308
# 	MaxRAMUsage_Stream/eval_phase/train_stream/Task004 = 1104.6172
# 	StreamBWT/eval_phase/train_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/train_stream = -0.0174
# 	Time_Stream/eval_phase/train_stream/Task004 = 3.0482
# Validation on test sets are completed

# %% [markdown]
# # **PNNStrategy**

# %%
# loading the benchmark and considering 5 experiences
split_mnist = SplitMNIST(n_experiences=5,return_task_id=True, seed=13)
print('--- Task labels:')
print(split_mnist.task_labels)

loggers = []

# log to text file
loggers.append(TextLogger(open('PNNStrategy_log.txt', 'a')))

# print to stdout
loggers.append(InteractiveLogger())
# PNN strategy requires PNN model for evaluation and due to this we can't use simpleMLP any more
model = PNN()
# defining the optimizer with constant parameters
optimizer = SGD(model.parameters(), lr=0.001, momentum=0.9)
# defining the loss function
criterion = CrossEntropyLoss()
# here the evaluation plugin defined
eval_plugin = EvaluationPlugin(
    accuracy_metrics(experience=True),
    bwt_metrics(experience=True),
    forward_transfer_metrics(experience=True),
    timing_metrics(experience=True,stream=True),
    cpu_usage_metrics(experience=True,stream=True),
    ram_usage_metrics( experience=True, stream=True),
    StreamForwardTransfer(),
    StreamBWT(),

        loggers=loggers,
        collect_all=False,
        strict_checks=False
)



cl_strategy = PNNStrategy(
    model, optimizer,
    CrossEntropyLoss(), train_mb_size=512, train_epochs=10, eval_mb_size=512,
    evaluator=eval_plugin,eval_every=1,
     plugins=[EarlyStoppingPlugin(patience=3, val_stream_name='train')])
# Out:
# --- Task labels:
# [[0], [1], [2], [3], [4]]

# %%
# saving the results of evaluation.
results = []

for experience in split_mnist.train_stream:
    # train returns a dictionary which contains all the metric values
    print("Start of experience::::: ", experience.current_experience)
    print("Current Classes::::: ", experience.classes_in_this_experience)
    cl_strategy.train(experience,eval_streams=[split_mnist.test_stream])
    print('Training completed')

    print('Computing accuracy on the whole test set')
    # test also returns a dictionary which contains all the metric values
    results.append(cl_strategy.eval(experience))
    print('Validation on test sets are completed')
# Out:
# Start of experience:::::  0
# Current Classes:::::  [8, 5]
# -- >> Start of training phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 12.03it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 89.4964
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3354
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.81it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 98.7045
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3649
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.82it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 95.3794
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4091
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.10it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 99.2607
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4939
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.31it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 97.2631
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4834
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.4145
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.4805
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.2509
# 100%|██████████| 23/23 [00:02<00:00, 11.44it/s]
# Epoch 0 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.63it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.6291
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3417
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5820
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.71it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 100.4022
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3687
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.99it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 97.3497
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4418
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.35it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.1965
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6831
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.87it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 99.8851
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.6808
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 97.0162
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.4805
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.6802
# 100%|██████████| 23/23 [00:03<00:00,  6.91it/s]
# Epoch 1 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 12.06it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 99.3394
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3322
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.6618
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.85it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 97.4603
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3696
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.08it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 97.6677
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3995
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.24it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 98.1299
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4893
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.64it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 97.2263
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4630
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.8553
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.4805
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.2097
# 100%|██████████| 23/23 [00:02<00:00, 11.39it/s]
# Epoch 2 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.97it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.3414
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3324
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.7192
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.52it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 99.6099
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3816
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.12it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 97.3641
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.3905
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.78it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 98.8531
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4656
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.11it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 97.8653
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4908
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 98.1442
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.4805
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.2112
# 100%|██████████| 23/23 [00:02<00:00,  8.31it/s]
# Epoch 3 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.44it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.9427
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4776
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.7519
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.77it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 95.4504
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5136
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.10it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 95.9925
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5627
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  6.81it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 92.7082
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.7337
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  4.92it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 92.4073
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.8117
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 93.8182
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.4805
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.2937
# 100%|██████████| 23/23 [00:02<00:00, 11.34it/s]
# Epoch 4 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.66it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 91.3902
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3721
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.7824
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.19it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 101.5506
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3547
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.75it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 97.4935
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4104
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.48it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 98.1854
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4789
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.43it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 97.0635
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4741
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.0608
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.4805
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.2493
# 100%|██████████| 23/23 [00:02<00:00, 11.26it/s]
# Epoch 5 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.87it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 99.1290
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3330
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8081
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.09it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 96.9539
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3610
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.08it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 100.3291
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4387
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  6.89it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 92.2073
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.7269
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.54it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 93.8569
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.7247
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.5590
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.4805
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.7602
# 100%|██████████| 23/23 [00:03<00:00,  7.49it/s]
# Epoch 6 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.59it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 92.5295
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.6055
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8264
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.50it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 94.1359
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.6162
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.03it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 97.8843
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6640
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.43it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.8183
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4802
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.28it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 99.3852
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4832
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.2227
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.4805
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.0373
# 100%|██████████| 23/23 [00:02<00:00, 11.22it/s]
# Epoch 7 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.02it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 98.2104
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3666
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8499
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.92it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 101.1397
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3661
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.96it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 99.2495
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4032
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.63it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 99.7157
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4714
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.82it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 96.5039
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5079
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 97.9396
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.4805
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.2664
# 100%|██████████| 23/23 [00:02<00:00, 11.28it/s]
# Epoch 8 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.74it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 93.0434
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3441
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8601
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.92it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 98.7771
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3647
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.53it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 94.1219
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6166
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.51it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 97.3266
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6680
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.54it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 92.9093
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.7214
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.7961
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.4805
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.8798
# 100%|██████████| 23/23 [00:03<00:00,  7.10it/s]
# Epoch 9 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.66it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 93.5983
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5985
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.41it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 95.4817
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.6180
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.85it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 94.9042
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5901
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.45it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.6340
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5335
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.82it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 95.0396
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5052
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.0297
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.4805
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.0418
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from train stream --
# 100%|██████████| 23/23 [00:02<00:00, 11.37it/s]
# > Eval on experience 0 (Task 0) from train stream ended.
# 	CPUUsage_Exp/eval_phase/train_stream/Task000/Exp000 = 97.3305
# 	MaxRAMUsage_Experience/eval_phase/train_stream/Task000/Exp000 = 1149.4805
# 	Time_Exp/eval_phase/train_stream/Task000/Exp000 = 2.0242
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp000 = 0.8456
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/train_stream/Task000 = 97.1587
# 	MaxRAMUsage_Stream/eval_phase/train_stream/Task000 = 1149.4805
# 	StreamBWT/eval_phase/train_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/train_stream = 0.0000
# 	Time_Stream/eval_phase/train_stream/Task000 = 2.0585
# Validation on test sets are completed
# Start of experience:::::  1
# Current Classes:::::  [4, 6]
# -- >> Start of training phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 12.02it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 99.0209
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3335
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.10it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 99.0151
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3940
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.21it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.5485
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4352
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.45it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 99.9517
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4804
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.93it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 100.4972
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5077
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 97.8356
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.4805
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.3098
# 100%|██████████| 23/23 [00:02<00:00,  8.68it/s]
# Epoch 0 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.46it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 90.9132
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5392
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.21it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 91.4345
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5582
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5964
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.74it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 92.4900
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5949
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  6.87it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 89.0261
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.7302
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.56it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 94.9456
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.7166
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 90.9787
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.4805
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.3416
# 100%|██████████| 23/23 [00:03<00:00,  7.52it/s]
# Epoch 1 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.84it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 98.1444
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3364
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.76it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 93.8284
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3732
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.8031
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.25it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 94.4891
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4341
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.82it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 98.4586
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5688
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.97it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 95.9001
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5007
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.9500
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.4805
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.3911
# 100%|██████████| 23/23 [00:02<00:00, 10.08it/s]
# Epoch 2 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.71it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.7713
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3411
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.79it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 99.5915
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4118
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.8964
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.29it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 94.0962
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4252
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.75it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 94.9751
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5162
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.05it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 98.3597
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4984
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.5378
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.4805
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.3656
# 100%|██████████| 23/23 [00:03<00:00,  7.32it/s]
# Epoch 3 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.84it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 85.6171
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5142
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.34it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 89.5797
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5471
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9299
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.67it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 93.3510
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6002
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  6.83it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 89.7235
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.7317
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.03it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 93.2472
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.7936
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 90.3251
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.4805
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.3988
# 100%|██████████| 23/23 [00:02<00:00,  8.93it/s]
# Epoch 4 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.17it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 95.7477
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4388
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.36it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 97.8327
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4295
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9392
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.06it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 99.7564
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4413
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.60it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 93.6198
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5234
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.52it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 96.8669
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5268
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.8880
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.4805
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.5238
# 100%|██████████| 23/23 [00:02<00:00,  9.70it/s]
# Epoch 5 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.84it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 97.9609
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3371
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.91it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 96.0560
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3957
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9433
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.72it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 94.1172
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4571
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.07it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 98.1899
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4992
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.79it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 95.3130
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5142
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.9526
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1149.4805
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.3696
# 100%|██████████| 23/23 [00:03<00:00,  6.62it/s]
# Epoch 6 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.71it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 91.7174
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5998
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.27it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 92.6774
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1149.4805
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.6367
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9490
# ...
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 100.4819
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1108.8828
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4779
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.8923
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.74it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.2384
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1108.8828
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5778
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.9865
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.80it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 98.6139
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5884
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9935
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.8582
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1108.8828
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.1220
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.7152
# 100%|██████████| 24/24 [00:04<00:00,  5.25it/s]
# Epoch 5 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.92it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 86.3295
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5792
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.67it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 82.0526
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1108.8828
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5974
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9562
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.37it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 88.3434
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6229
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.8923
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.48it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 92.2648
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1108.8828
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6722
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.9865
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.48it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 90.8634
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1108.8828
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.7266
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9935
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 87.1669
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1108.8828
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.1220
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.4302
# 100%|██████████| 24/24 [00:04<00:00,  4.97it/s]
# Epoch 6 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.31it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.4140
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4358
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.61it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 94.5060
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4658
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9562
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.98it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 98.0063
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5002
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.8923
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.67it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.4497
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1108.8828
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5765
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.9865
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.87it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 94.6529
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5813
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9935
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.7373
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1108.8828
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.1220
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.7550
# 100%|██████████| 24/24 [00:04<00:00,  5.95it/s]
# Epoch 7 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.33it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 80.5155
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5465
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.81it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 84.7264
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1108.8828
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5905
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9562
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.31it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 86.5670
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6356
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.8923
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  6.83it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 88.8059
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1108.8828
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.7323
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.9865
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.10it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 85.2667
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1108.8828
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.7857
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9935
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 85.5043
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1108.8828
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.1220
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.4967
# 100%|██████████| 24/24 [00:05<00:00,  4.59it/s]
# Epoch 8 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.63it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.0483
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4168
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.74it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 95.1450
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4627
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9562
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.26it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.3369
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1108.8828
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5503
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.8923
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  8.30it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 96.3436
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1108.8828
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6021
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.9865
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.79it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 96.4672
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5911
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9935
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.6774
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1108.8828
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.1220
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.8132
# 100%|██████████| 24/24 [00:03<00:00,  6.16it/s]
# Epoch 9 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.69it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 95.4826
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4192
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.62it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 94.1826
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4674
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9562
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.10it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 92.1327
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1108.8828
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4995
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.8923
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.90it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 91.4983
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1108.8828
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6340
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.9865
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.45it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 91.4211
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.7331
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9935
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 92.6454
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1108.8828
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.1220
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.9361
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 4 (Task 4) from train stream --
# 100%|██████████| 24/24 [00:04<00:00,  5.28it/s]
# > Eval on experience 4 (Task 4) from train stream ended.
# 	CPUUsage_Exp/eval_phase/train_stream/Task004/Exp004 = 88.7305
# 	MaxRAMUsage_Experience/eval_phase/train_stream/Task004/Exp004 = 1108.8828
# 	Time_Exp/eval_phase/train_stream/Task004/Exp004 = 4.5419
# 	Top1_Acc_Exp/eval_phase/train_stream/Task004/Exp004 = 0.9955
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/train_stream/Task004 = 88.8890
# 	MaxRAMUsage_Stream/eval_phase/train_stream/Task004 = 1108.8828
# 	StreamBWT/eval_phase/train_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/train_stream = 0.4880
# 	Time_Stream/eval_phase/train_stream/Task004 = 4.5781
# Validation on test sets are completed

# %% [markdown]
# # **GEM**

# %%
# loading the benchmark and considering 5 experiences
split_mnist = SplitMNIST(n_experiences=5,return_task_id=True, seed=13)
print('--- Task labels:')
print(split_mnist.task_labels)

loggers = []

# log to text file
loggers.append(TextLogger(open('GEM_log.txt', 'a')))

# print to stdout
loggers.append(InteractiveLogger())
# PNN strategy requires PNN model for evaluation and due to this we can't use simpleMLP any more
model = PNN()
# defining the optimizer with constant parameters
optimizer = SGD(model.parameters(), lr=0.001, momentum=0.9)
# defining the loss function
criterion = CrossEntropyLoss()
# here the evaluation plugin defined
eval_plugin = EvaluationPlugin(
    accuracy_metrics(experience=True),
    bwt_metrics(experience=True),
    forward_transfer_metrics(experience=True),
    timing_metrics(experience=True,stream=True),
    cpu_usage_metrics(experience=True,stream=True),
    ram_usage_metrics( experience=True, stream=True),
    StreamForwardTransfer(),
    StreamBWT(),

        loggers=loggers,
        collect_all=False,
        strict_checks=False
)


# GEM requires patterns_per_exp. here we put a constant value but this should be tuned in training phase.
# patterns_per_exp – number of patterns per experience in the memory
cl_strategy = GEM(
    model, optimizer,
    CrossEntropyLoss(), train_mb_size=512, train_epochs=10, eval_mb_size=512,
    evaluator=eval_plugin,eval_every=1,patterns_per_exp = 100,
     plugins=[EarlyStoppingPlugin(patience=3, val_stream_name='train')])
# Out:
# --- Task labels:
# [[0], [1], [2], [3], [4]]

# %%
# saving the results of evaluation.
results = []

for experience in split_mnist.train_stream:
    # train returns a dictionary which contains all the metric values
    print("Start of experience::::: ", experience.current_experience)
    print("Current Classes::::: ", experience.classes_in_this_experience)
    cl_strategy.train(experience,eval_streams=[split_mnist.test_stream])
    print('Training completed')

    print('Computing accuracy on the whole test set')
    # test also returns a dictionary which contains all the metric values
    results.append(cl_strategy.eval(experience))
    print('Validation on test sets are completed')
# Out:
# Start of experience:::::  0
# Current Classes:::::  [8, 5]
# -- >> Start of training phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.77it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 89.4216
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5148
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.0000
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.76it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 94.2161
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1155.2031
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5096
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.42it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 92.8781
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6247
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.11it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 92.1933
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1155.2031
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.7052
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.11it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 92.0035
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1155.2031
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.7828
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.0000
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 91.3158
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1155.2031
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.3733
# 100%|██████████| 23/23 [00:02<00:00,  9.17it/s]
# Epoch 0 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.47it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 99.4612
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3520
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5820
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.64it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 99.0824
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3737
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.67it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.8987
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1155.2031
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4129
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.65it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 99.9311
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4706
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.58it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 98.4977
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1155.2031
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4672
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 97.9145
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1155.2031
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.2366
# 100%|██████████| 23/23 [00:02<00:00, 11.02it/s]
# Epoch 1 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 12.01it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 99.8966
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3305
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.6618
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.28it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 98.4148
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3558
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.50it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.8194
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1155.2031
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4236
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.87it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 101.3191
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4640
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.04it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 98.6626
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1155.2031
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4968
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 97.8647
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1155.2031
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.2276
# 100%|██████████| 23/23 [00:02<00:00,  7.75it/s]
# Epoch 2 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.88it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 89.5475
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5139
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.7192
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.48it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 97.3470
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1155.2031
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.6164
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.54it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 94.3821
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.7207
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  6.10it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 94.9546
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.8216
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.89it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 94.8236
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1155.2031
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5063
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 93.7425
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1155.2031
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.3708
# 100%|██████████| 23/23 [00:02<00:00, 11.19it/s]
# Epoch 3 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.62it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 95.8217
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3445
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.7519
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.49it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 96.6756
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3828
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.72it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 96.5551
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1155.2031
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4145
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.63it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 100.0013
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5201
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.22it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 99.2119
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1155.2031
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4840
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 97.2766
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1155.2031
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.3025
# 100%|██████████| 23/23 [00:02<00:00, 11.06it/s]
# Epoch 4 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.41it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 93.9351
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4792
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.7824
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.70it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 96.1860
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1155.2031
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5201
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.65it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 93.3747
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5998
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.24it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 95.7366
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1155.2031
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6898
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.50it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 90.9118
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1155.2031
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.7262
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 92.7658
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1155.2031
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.2237
# 100%|██████████| 23/23 [00:03<00:00,  7.57it/s]
# Epoch 5 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.92it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.7002
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4137
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8081
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.23it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 98.8191
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3545
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.26it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 95.8546
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1155.2031
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4279
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.29it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 98.1943
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4890
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.07it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 96.7151
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1155.2031
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4964
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.0433
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1155.2031
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.3529
# 100%|██████████| 23/23 [00:02<00:00,  9.56it/s]
# Epoch 6 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.56it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 91.5988
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3494
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8264
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.49it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 99.2566
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3830
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.71it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 98.8901
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4149
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.23it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 97.3826
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4930
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.13it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 97.8021
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4908
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.2632
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1110.4102
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.3061
# 100%|██████████| 23/23 [00:02<00:00,  8.52it/s]
# Epoch 7 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.08it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 90.6330
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4966
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8499
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.14it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 90.1681
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5549
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.51it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 91.3896
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6129
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  6.58it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 90.4959
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.7628
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.14it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 94.6962
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.7818
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 91.1516
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1110.4102
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.4115
# 100%|██████████| 23/23 [00:02<00:00, 11.20it/s]
# Epoch 8 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.71it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 95.9013
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3442
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8601
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.62it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 97.5922
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3793
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.71it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 98.1826
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4076
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.92it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 94.6407
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5074
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.02it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 100.3493
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4984
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.7754
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1110.4102
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.3181
# 100%|██████████| 23/23 [00:02<00:00, 10.97it/s]
# Epoch 9 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.67it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 99.9185
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3505
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.88it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 99.9341
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3604
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.69it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 97.2289
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4116
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.99it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 96.2898
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6374
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.30it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 94.4661
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.7517
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.3381
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1110.4102
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.6850
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from train stream --
# 100%|██████████| 23/23 [00:03<00:00,  7.00it/s]
# > Eval on experience 0 (Task 0) from train stream ended.
# 	CPUUsage_Exp/eval_phase/train_stream/Task000/Exp000 = 93.1525
# 	MaxRAMUsage_Experience/eval_phase/train_stream/Task000/Exp000 = 1110.4102
# 	Time_Exp/eval_phase/train_stream/Task000/Exp000 = 3.2855
# 	Top1_Acc_Exp/eval_phase/train_stream/Task000/Exp000 = 0.8456
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/train_stream/Task000 = 92.8502
# 	MaxRAMUsage_Stream/eval_phase/train_stream/Task000 = 1110.4102
# 	StreamBWT/eval_phase/train_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/train_stream = 0.0000
# 	Time_Stream/eval_phase/train_stream/Task000 = 3.3171
# Validation on test sets are completed
# Start of experience:::::  1
# Current Classes:::::  [4, 6]
# -- >> Start of training phase << --
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.57it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.9371
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3406
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.86it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 97.4520
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task001/Exp001 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3696
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.0000
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.34it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 94.9225
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4321
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.10it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 94.6591
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4967
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.20it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 98.4124
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4879
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.1224
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1110.4102
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.2991
# 100%|██████████| 23/23 [00:02<00:00,  8.98it/s]
# Epoch 0 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.58it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 98.1332
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3466
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.98it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 98.7180
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3648
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5959
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.36it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 97.6281
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4303
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.81it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 93.4014
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5141
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.01it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 99.8420
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5011
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 97.0924
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1110.4102
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.3173
# 100%|██████████| 23/23 [00:03<00:00,  6.02it/s]
# Epoch 1 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.45it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 92.7176
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.6150
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.22it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 95.0333
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.6420
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.8036
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.54it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 91.2319
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.7234
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.36it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 98.5951
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5376
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.93it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 96.9564
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5055
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 92.9033
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1110.4102
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.2289
# 100%|██████████| 23/23 [00:02<00:00,  8.89it/s]
# Epoch 2 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.83it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 97.9442
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3371
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 10.63it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 98.8784
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.3845
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.8959
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.46it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 97.0501
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5359
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.94it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 97.1387
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5150
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.00it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 100.0331
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5001
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 97.8783
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1110.4102
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.4313
# 100%|██████████| 23/23 [00:03<00:00,  6.89it/s]
# Epoch 3 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.85it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 87.6672
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5133
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.42it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 90.4487
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5419
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9294
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.70it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 92.6809
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5937
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.25it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 94.4449
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6885
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.58it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 93.4924
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.7168
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 90.1357
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1110.4102
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.2732
# 100%|██████████| 23/23 [00:03<00:00,  7.16it/s]
# Epoch 4 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.16it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 91.8610
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3594
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.25it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 94.3037
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4350
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9392
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  8.92it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 100.5678
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4476
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00, 10.08it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 98.5378
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.4974
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.80it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 95.9304
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5110
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 95.8312
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1110.4102
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.4226
# 100%|██████████| 23/23 [00:02<00:00,  8.83it/s]
# Epoch 5 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00, 11.88it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 101.3123
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.3358
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.79it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 95.4726
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 0
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.4086
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9438
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.38it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 95.9499
# 	ExperienceForwardTransfer/eval_phase/test_stream/Task002/Exp002 = 0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.4275
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.0000
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  9.68it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 98.3723
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 0
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.5186
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.0000
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.74it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 97.0143
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.5157
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.4880
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 96.4809
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1110.4102
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.0000
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.3736
# 100%|██████████| 23/23 [00:03<00:00,  6.45it/s]
# Epoch 6 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.65it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 86.9980
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5290
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.33it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 90.7291
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1110.4102
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.6285
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9490
# ...
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1129.5664
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.6723
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.8908
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  5.34it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 79.1863
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1129.5664
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.9347
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.9865
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  4.25it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 83.2016
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1129.5664
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9380
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9935
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 82.6616
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1129.5664
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.1220
# 	Time_Stream/eval_phase/test_stream/Task004 = 4.1375
# 100%|██████████| 24/24 [00:05<00:00,  4.32it/s]
# Epoch 5 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.09it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 96.5888
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4454
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.42it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 92.5432
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1129.5664
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5295
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9562
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.75it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 95.6135
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5962
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.8908
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.39it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 92.4853
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1129.5664
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6815
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.9865
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.87it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 95.2246
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1129.5664
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.6828
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9935
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 93.1939
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1129.5664
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.1220
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.1760
# 100%|██████████| 24/24 [00:07<00:00,  3.39it/s]
# Epoch 6 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.09it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 78.3694
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.7916
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  4.61it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 81.3753
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1129.8242
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.8650
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9562
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:01<00:00,  3.99it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 78.4945
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1129.8242
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 1.0077
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.8908
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  5.97it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 88.3350
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1129.8242
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.8380
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.9865
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.45it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 95.2733
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1129.8242
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.7348
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9935
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 83.1782
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1129.8242
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.1220
# 	Time_Stream/eval_phase/test_stream/Task004 = 4.5444
# 100%|██████████| 24/24 [00:05<00:00,  4.25it/s]
# Epoch 7 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.62it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 91.0917
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.5272
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.70it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 94.8835
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1129.8281
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5165
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9562
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.99it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 93.4871
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5779
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.8908
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.42it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 93.2988
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1129.8281
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6757
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.9865
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  4.33it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 85.5903
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1129.8281
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9230
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9935
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 90.4982
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1129.8281
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.1220
# 	Time_Stream/eval_phase/test_stream/Task004 = 3.4363
# 100%|██████████| 24/24 [00:06<00:00,  3.43it/s]
# Epoch 8 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  9.28it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 94.3191
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.4347
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.41it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 91.1951
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1129.8281
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.5376
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9562
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  7.21it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 95.5437
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 0
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.5548
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.8908
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  7.92it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 97.9457
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1129.8281
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.6332
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.9865
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.50it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 96.0521
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 0
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.6149
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9935
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 94.2535
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1129.8281
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.1220
# 	Time_Stream/eval_phase/test_stream/Task004 = 2.9815
# 100%|██████████| 24/24 [00:05<00:00,  4.38it/s]
# Epoch 9 ended.
# -- >> Start of eval phase << --
# -- Starting eval on experience 0 (Task 0) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  6.49it/s]
# > Eval on experience 0 (Task 0) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task000/Exp000 = 86.2693
# 	ExperienceBWT/eval_phase/test_stream/Task000/Exp000 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task000/Exp000 = 0
# 	Time_Exp/eval_phase/test_stream/Task000/Exp000 = 0.6263
# 	Top1_Acc_Exp/eval_phase/test_stream/Task000/Exp000 = 0.8644
# -- Starting eval on experience 1 (Task 1) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  4.43it/s]
# > Eval on experience 1 (Task 1) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task001/Exp001 = 76.2573
# 	ExperienceBWT/eval_phase/test_stream/Task001/Exp001 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task001/Exp001 = 1129.8281
# 	Time_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9051
# 	Top1_Acc_Exp/eval_phase/test_stream/Task001/Exp001 = 0.9562
# -- Starting eval on experience 2 (Task 2) from test stream --
# 100%|██████████| 4/4 [00:00<00:00,  5.02it/s]
# > Eval on experience 2 (Task 2) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task002/Exp002 = 80.1230
# 	ExperienceBWT/eval_phase/test_stream/Task002/Exp002 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task002/Exp002 = 1129.8281
# 	Time_Exp/eval_phase/test_stream/Task002/Exp002 = 0.7992
# 	Top1_Acc_Exp/eval_phase/test_stream/Task002/Exp002 = 0.8908
# -- Starting eval on experience 3 (Task 3) from test stream --
# 100%|██████████| 5/5 [00:00<00:00,  5.60it/s]
# > Eval on experience 3 (Task 3) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task003/Exp003 = 83.6024
# 	ExperienceBWT/eval_phase/test_stream/Task003/Exp003 = -0.0000
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task003/Exp003 = 1129.8281
# 	Time_Exp/eval_phase/test_stream/Task003/Exp003 = 0.8975
# 	Top1_Acc_Exp/eval_phase/test_stream/Task003/Exp003 = 0.9865
# -- Starting eval on experience 4 (Task 4) from test stream --
# 100%|██████████| 4/4 [00:01<00:00,  4.00it/s]
# > Eval on experience 4 (Task 4) from test stream ended.
# 	CPUUsage_Exp/eval_phase/test_stream/Task004/Exp004 = 83.5026
# 	MaxRAMUsage_Experience/eval_phase/test_stream/Task004/Exp004 = 1129.8281
# 	Time_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9943
# 	Top1_Acc_Exp/eval_phase/test_stream/Task004/Exp004 = 0.9935
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/test_stream/Task004 = 81.8516
# 	MaxRAMUsage_Stream/eval_phase/test_stream/Task004 = 1129.8281
# 	StreamBWT/eval_phase/test_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/test_stream = 0.1220
# 	Time_Stream/eval_phase/test_stream/Task004 = 4.4717
# -- >> End of training phase << --
# Training completed
# Computing accuracy on the whole test set
# -- >> Start of eval phase << --
# -- Starting eval on experience 4 (Task 4) from train stream --
# 100%|██████████| 24/24 [00:05<00:00,  4.36it/s]
# > Eval on experience 4 (Task 4) from train stream ended.
# 	CPUUsage_Exp/eval_phase/train_stream/Task004/Exp004 = 86.3155
# 	MaxRAMUsage_Experience/eval_phase/train_stream/Task004/Exp004 = 1129.8281
# 	Time_Exp/eval_phase/train_stream/Task004/Exp004 = 5.5038
# 	Top1_Acc_Exp/eval_phase/train_stream/Task004/Exp004 = 0.9955
# -- >> End of eval phase << --
# 	CPUUsage_Stream/eval_phase/train_stream/Task004 = 86.2422
# 	MaxRAMUsage_Stream/eval_phase/train_stream/Task004 = 1129.8281
# 	StreamBWT/eval_phase/train_stream = 0.0000
# 	StreamForwardTransfer/eval_phase/train_stream = 0.4880
# 	Time_Stream/eval_phase/train_stream/Task004 = 5.5430
# Validation on test sets are completed

# %% [markdown]
# # **Evaluation**
# ### Now is the time to evaluate strategies based on different criteria. We have 9 strategies to compare. First of all, we compare strategies based on CPU and RAM usage and the amount of time that takes one training procedure finishes. Then we go to the most important part to evaluate strategies based on ACC, BWT, and FWT.

# %% [markdown]
# **A quick recap about algorithms:**
#
# **Naive:** This is a single-task learning strategy. This means while new experience comes it doesn't consider previous ones. Then we expect to have catastrophic forgetting here.
#
# **Replay:** Mix old experiences samples with new ones and train the model.
#
# **GDUMB:** Aims to address the catastrophic forgetting problem by maintaining an unbiased memory buffer of previously learned tasks and using it to update the neural network weights during training on new tasks.
#
# **LWF:** The LWF strategy works by training the neural network on a combination of the current task and a subset of previously learned tasks. During training, the loss function is modified to include a distillation term, which encourages the neural network to produce similar outputs for both the current task and the previously learned tasks.
#
# **EWC:** This adds a regularization term to penalize changes on important parameters of previous tasks. in this way, we can deal with catastrophic forgetting by remembering the past task parameters.
#
# **CWRstar:** The CWRstar strategy works by modifying the loss function used for training the neural network. During training on a new task, the CWRstar algorithm adds a penalty term to the loss function that encourages the neural network to assign similar weights to the classes in the new task as in the previous tasks. This helps to prevent the neural network from overfitting to the new task and forgetting the previous tasks.
#
# **PNN:** The PNN strategy works by modifying the architecture of the neural network. During training on a new task, the PNN algorithm adds a new neural network module that is trained to perform the new task while reusing the knowledge stored in the previous modules. The outputs of the previous modules are used as inputs to the new module, allowing it to incorporate the information learned from the previous tasks. Main focus on the forward transfer and re-use of previously acquired representational power
#
# GEM: is like a mix of replay and regularization strategies. During training on a new task, the GEM algorithm stores a set of examples from the new task in the memory buffer and constrains the updates to the neural network weights to be consistent with the predictions made on the examples in the memory buffer.

# %% [markdown]
# **Comparison between strategies:**

# %%
directory = "/drive/My Drive/Colab Notebooks/SDA project/mnist"
# Define a list of filenames to read
filenames = ["naive_log.txt", "replay_log.txt", "EWC_log.txt", "LwF_log.txt", "GDumb_log.txt", "CWRstar_log.txt", "PNNStrategy_log.txt", "GEM_log.txt"]
# Loop over each filename and read its contents
time = []
CPU = []
RAM = []
FWT = []
BWT = []
for filename in filenames:
  filepath = os.path.join(directory, filename)
  with open(filepath, "r") as f:
      log_contents = f.read()
      # Do something with the file contents
      lines = log_contents.split('\n')
      filtered_list = [elem for elem in lines if '--' not in elem]
      filtered_list = [elem for elem in filtered_list if '>' not in elem]
      filtered_list = [elem for elem in filtered_list if 'Epoch' not in elem]
      filtered_list = [elem for elem in filtered_list if elem]

      key_value_pairs = [elem.split('=') for elem in filtered_list]

      # Use a dictionary comprehension to create a dictionary from the key-value pairs
      my_dict = {pair[0]: (pair[1]) for pair in key_value_pairs}

      # Loop through each line of the log file
      search_string = 'Time_Stream/eval_phase/train_stream'
      # Use a list comprehension to extract the values for keys that contain the search string
      Time_usage = [float(my_dict[key]) for key in my_dict if search_string in key]
      time.append(Time_usage)

      search_string = 'CPUUsage_Stream/eval_phase/train_stream'
      CPU_usage = [float(my_dict[key]) for key in my_dict if search_string in key]
      CPU.append(CPU_usage)

      search_string = 'MaxRAMUsage_Stream/eval_phase/train_stream'
      RAM_usage = [float(my_dict[key]) for key in my_dict if search_string in key]
      RAM.append(RAM_usage)

      search_string = 'StreamForwardTransfer/eval_phase/test_stream'
      f_transform = [float(my_dict[key]) for key in my_dict if search_string in key]
      FWT.append(f_transform)

      search_string = 'StreamBWT/eval_phase/test_stream'
      b_transform = [float(my_dict[key]) for key in my_dict if search_string in key]
      BWT.append(b_transform)

# %% [markdown]
# **Running time:**

# %%
categories = ['Naive','Replay','EWC', 'LwF', 'GDumb','CWRStar','PNN\nstrategy','GEM']

# %%
fig, ax = plt.subplots()
ax.boxplot(time)
# set the labels for the x-axis and y-axis
ax.set_xticklabels(categories)
ax.set_ylabel('Training time')
ax.set_xlabel('strategies')
# show the plot
plt.show()

# %%
row_sums = [sum(row) for row in time]
plt.bar(categories, row_sums)
plt.ylabel('Whole of the stream training time')
plt.xlabel('strategies')
plt.show()

# %% [markdown]
# It is clear PNN and GEM have pretty much running time. GEM uses a combination of the Replay and regularization methods and again is a more complex model than others. But all in all, all the algorithms have similar running times because we are using SimpleMLP which is not so much a complex model on its own.

# %% [markdown]
# **CPU usage**

# %%
fig, ax = plt.subplots()
ax.boxplot(CPU)
# set the labels for the x-axis and y-axis
ax.set_xticklabels(categories)
plt.ylabel('CPU usage')
plt.xlabel('strategies')
# show the plot
plt.show()

# %%
row_sums = [statistics.mean(row) for row in CPU]
plt.bar(categories, row_sums)
plt.ylabel('Average CPU usage in whole stream')
plt.xlabel('strategies')
plt.show()

# %% [markdown]
# It is hard to compare based on CPU usage. But we can see in methods based on replay and PNN we have a bit more CPU usage.

# %% [markdown]
# **RAM usage**

# %%
fig, ax = plt.subplots()
ax.boxplot(RAM)
# set the labels for the x-axis and y-axis
ax.set_xticklabels(categories)
ax.set_ylabel('RAM usage')
ax.set_xlabel('strategies')
# show the plot
plt.show()

# %%
row_sums = [sum(row) for row in RAM]
plt.bar(categories, row_sums)
plt.ylabel('RAM usage')
plt.xlabel('strategies')
plt.show()

# %% [markdown]
# As we mentioned in previous steps, models based on replay and naive strategies just use the samples for training without any adding parameters to the loss function. This way these have less RAM usage. in the above chart we can see Naive, Replay, and GDUMB have less ram usage than others. LwF only stores the knowledge from the previous task and transfers it to the current task, whereas EWC stores the importance of each weight for every task, which can lead to a significant increase in memory usage. PNN algorithm adds a new neural network module that is trained to perform the new task while reusing the knowledge stored in the previous modules. The CWRstar strategy works by modifying the loss function used for training the neural network. By doing so, these two methods have more RAM usage usually. GEM is a hybrid method and as it benefits the regularization approach it consumes more RAM.

# %% [markdown]
# **ACC, plasticity, and catastrophic comparison**

# %%
# data
x = np.array([1, 2, 3, 4, 5])
y1 = np.array([0.9646 ,0.     ,0.     ,0.     ,0.    ])
y2 = np.array([0.     ,0.9861 ,0.     ,0.     ,0.    ])
y3 = np.array([0.     ,0.     ,0.9716 ,0.     ,0.    ])
y4 = np.array([0.     ,0.     ,0.     ,0.9944 ,0.1735])
y5 = np.array([0.     ,0.     ,0.     ,0.     ,0.9935])

fig = plt.figure(figsize=(15, 2))
# plot bars
width = 0.2
plt.bar(x - 2*width, y1, width=width,)
plt.bar(x - width, y2, width=width,)
plt.bar(x, y3, width=width,)
plt.bar(x + width, y4, width=width,)
plt.bar(x + 2*width, y5, width=width,)
plt.xlabel('experiences')
plt.ylabel('ACC in percentage')
plt.title('Naive')
plt.xticks(x, ['exp1', 'exp2', 'exp3', 'exp4', 'exp5'])
plt.show()

# data
x = np.array([1, 2, 3, 4, 5])
y1 = np.array([0.9646, 0.9035, 0.7020, 0.7412, 0.7074])
y2 = np.array([0.0000, 0.9722, 0.9021, 0.7211, 0.8113])
y3 = np.array([0.0000, 0.0000, 0.9520, 0.8056, 0.7821])
y4 = np.array([0.0000, 0.0000, 0.0000, 0.9813, 0.7500])
y5 = np.array([0.0000, 0.0000, 0.0000, 0.0000, 0.9816])

fig = plt.figure(figsize=(15, 2))
# plot bars
width = 0.2
plt.bar(x - 2*width, y1, width=width,)
plt.bar(x - width, y2, width=width,)
plt.bar(x, y3, width=width,)
plt.bar(x + width, y4, width=width,)
plt.bar(x + 2*width, y5, width=width,)
plt.xlabel('experiences')
plt.ylabel('ACC in percentage')
plt.title('Replay')
plt.xticks(x, ['exp1', 'exp2', 'exp3', 'exp4', 'exp5'])
plt.show()

# data
x = np.array([1, 2, 3, 4, 5])
y1 = np.array([0.9646, 0.0000, 0.0000, 0.0000, 0.0000])
y2 = np.array([0.0000, 0.9861, 0.0000, 0.0000, 0.0000])
y3 = np.array([0.0000, 0.0000, 0.9711, 0.0010, 0.0000])
y4 = np.array([0.0000, 0.0000, 0.0000, 0.9949, 0.1754])
y5 = np.array([0.0000, 0.0000, 0.0000, 0.0000, 0.9935])

fig = plt.figure(figsize=(15, 2))
# plot bars
width = 0.2
plt.bar(x - 2*width, y1, width=width,)
plt.bar(x - width, y2, width=width,)
plt.bar(x, y3, width=width,)
plt.bar(x + width, y4, width=width,)
plt.bar(x + 2*width, y5, width=width,)
plt.xlabel('experiences')
plt.ylabel('ACC in percentage')
plt.title('EWC')
plt.xticks(x, ['exp1', 'exp2', 'exp3', 'exp4', 'exp5'])
plt.show()

# data
x = np.array([1, 2, 3, 4, 5])
y1 = np.array([0.9646, 0.0000, 0.0000, 0.0000, 0.0000])
y2 = np.array([0.0000, 0.9861, 0.0000, 0.0000, 0.0000])
y3 = np.array([0.0000, 0.0000, 0.9701, 0.0010, 0.0000])
y4 = np.array([0.0000, 0.0000, 0.0000, 0.9949, 0.1968])
y5 = np.array([0.0000, 0.0000, 0.0000, 0.0000, 0.9945])

fig = plt.figure(figsize=(15, 2))
# plot bars
width = 0.2
plt.bar(x - 2*width, y1, width=width,)
plt.bar(x - width, y2, width=width,)
plt.bar(x, y3, width=width,)
plt.bar(x + width, y4, width=width,)
plt.bar(x + 2*width, y5, width=width,)
plt.xlabel('experiences')
plt.ylabel('ACC in percentage')
plt.title('LWF')
plt.xticks(x, ['exp1', 'exp2', 'exp3', 'exp4', 'exp5'])
plt.show()

# data
x = np.array([1, 2, 3, 4, 5])
y1 = np.array([0.5461, 0.4984, 0.3226, 0.2803, 0.2283])
y2 = np.array([0.0000, 0.3722, 0.1247, 0.0912, 0.0562])
y3 = np.array([0.0000, 0.0029, 0.5313, 0.4706, 0.4280])
y4 = np.array([0.0000, 0.0000, 0.0000, 0.0508, 0.0429])
y5 = np.array([0.0000, 0.0000, 0.0000, 0.0000, 0.0936])

fig = plt.figure(figsize=(15, 2))
# plot bars
width = 0.2
plt.bar(x - 2*width, y1, width=width,)
plt.bar(x - width, y2, width=width,)
plt.bar(x, y3, width=width,)
plt.bar(x + width, y4, width=width,)
plt.bar(x + 2*width, y5, width=width,)
plt.xlabel('experiences')
plt.ylabel('ACC in percentage')
plt.title('GDumb')
plt.xticks(x, ['exp1', 'exp2', 'exp3', 'exp4', 'exp5'])
plt.show()

# data
x = np.array([1, 2, 3, 4, 5])
y1 = np.array([0.9636, 0.0000, 0.0000, 0.0000, 0.6618])
y2 = np.array([0.0000, 0.9778, 0.0000, 0.0000, 0.5469])
y3 = np.array([0.0000, 0.0000, 0.9525, 0.0000, 0.5264])
y4 = np.array([0.0000, 0.0000, 0.0000, 0.9935, 0.8773])
y5 = np.array([0.0000, 0.0000, 0.0000, 0.0000, 0.6111])

fig = plt.figure(figsize=(15, 2))
# plot bars
width = 0.2
plt.bar(x - 2*width, y1, width=width,)
plt.bar(x - width, y2, width=width,)
plt.bar(x, y3, width=width,)
plt.bar(x + width, y4, width=width,)
plt.bar(x + 2*width, y5, width=width,)
plt.xlabel('experiences')
plt.ylabel('ACC in percentage')
plt.title('CWRStar')
plt.xticks(x, ['exp1', 'exp2', 'exp3', 'exp4', 'exp5'])
plt.show()

# data
x = np.array([1, 2, 3, 4, 5])
y1 = np.array([0.8644, 0.8644, 0.8644, 0.8644, 0.8644])
y2 = np.array([0.    , 0.9562, 0.9562, 0.9562, 0.9562])
y3 = np.array([0.    , 0.    , 0.8908, 0.8908, 0.8908])
y4 = np.array([0.    , 0.    , 0.    , 0.9865, 0.9865])
y5 = np.array([0.488 , 0.488 , 0.488 , 0.488 , 0.9935])

fig = plt.figure(figsize=(15, 2))
# plot bars
width = 0.2
plt.bar(x - 2*width, y1, width=width,)
plt.bar(x - width, y2, width=width,)
plt.bar(x, y3, width=width,)
plt.bar(x + width, y4, width=width,)
plt.bar(x + 2*width, y5, width=width,)
plt.xlabel('experiences')
plt.ylabel('ACC in percentage')
plt.title('PNNstrategy')
plt.xticks(x, ['exp1', 'exp2', 'exp3', 'exp4', 'exp5'])
plt.show()

# data
x = np.array([1, 2, 3, 4, 5])
y1 = np.array([0.8644, 0.8644, 0.8644, 0.8644, 0.8644])
y2 = np.array([0.0000, 0.9562, 0.9562, 0.9562, 0.9562])
y3 = np.array([0.0000, 0.0000, 0.8923, 0.8923, 0.8923])
y4 = np.array([0.0000, 0.0000, 0.0000, 0.9865, 0.9865])
y5 = np.array([0.4880, 0.4880, 0.4880, 0.4880, 0.9935])

fig = plt.figure(figsize=(15, 2))
# plot bars
width = 0.2
plt.bar(x - 2*width, y1, width=width,)
plt.bar(x - width, y2, width=width,)
plt.bar(x, y3, width=width,)
plt.bar(x + width, y4, width=width,)
plt.bar(x + 2*width, y5, width=width,)
plt.xlabel('experiences')
plt.ylabel('ACC in percentage')
plt.title('GEM')
plt.xticks(x, ['exp1', 'exp2', 'exp3', 'exp4', 'exp5'])
plt.show()

# %% [markdown]
# **Naive:**
# Here when a new experience comes we just train the new one. Then we have catastrophic forgetting. In some cases, we are seeing there is backward transfer but accuracy is not so much significant in these cases. Also, we can see too much plasticity here.
#
# **Replay:**
# While we are using past samples in the new experience training procedure it deals with catastrophic forgetting. As we see although the ACC related to previous tasks decreases, the trained model doesn't forget completely the past tasks. This forgetting amount is not so much here. Here we do not have any forward or backward transfer. The model has more plasticity, it means we are learning new tasks in the right way.
#
# **GDUMB:**
# It is a bit similar to the replay strategy, there is catastrophic forgetting and the model is without plasticity. Not only it forgets past tasks, but also it can't learn new tasks as well. there is no backward transfer, but we can see a negligible forward transfer in some cases. Here the forgetting the past task is more than Replay method.
#
# **LWF:**
# There is catastrophic forgetting without any forward and backward transfer. here the plasticity is pretty high and models can acquire new knowledge easily.
#
# **CWRStar:**
# Here there plasticity and model can learn new tasks, but there exists catastrophic forgetting. There is no forward and backward transfer. But the important thing is that while the model trained on the last experience was able to learn all previous tasks in the Cifar10 benchmark we hadn't such a thing.
#
# **PNN:**
# Here there is no catastrophic forgetting it means the model doesn't forget a previous task while training on the new task. There exists forward transfer but without any backward transfer. there is plasticity here, it means the model can acquire new knowledge and keep learning over time.
#
# **GEM:**
# Here there is no catastrophic forgetting it means the model doesn't forget a previous task while training on the new task. There exists forward transfer but without any backward transfer. there is plasticity here, it means the model can acquire new knowledge and keep learning over time. These results are completely different as Cifar10 benchmark.

# %% [markdown]
# **FWT**

# %%
categories = ['Naive','Replay','EWC', 'LwF', 'GDumb','CWR\nStar','PNN\nstrategy','GEM']
numbers = np.array(FWT).flatten()
# Add labels to the plot
plt.title('FWT')
plt.xlabel('Category')
plt.ylabel('Values')
plt.ylim(-0.2, 0.2)
plt.bar(categories, numbers)
# Show the plot
plt.show()

# %% [markdown]
# FWT metric is a performance metric used to evaluate the ability of a continual learning model to transfer knowledge from previous tasks to new tasks. In all strategies except PNN and GEM, we have negative values, which means PNN and GEM can improve performance in the next experiences. Negative values mean model performs worse than a random model for the next experiences.

# %% [markdown]
# **BWT**

# %%
categories = ['Naive','Replay','EWC', 'LwF', 'GDumb','CWR\nStar','PNN\nstrategy','GEM']
numbers = np.array(BWT).flatten()
# Add labels to the plot
plt.title('BWT')
plt.xlabel('Category')
plt.ylabel('Values')
plt.bar(categories, numbers)
plt.ylim(-1, 0.5)
# Show the plot
plt.show()

# %% [markdown]
# BWT measures how the final model has improved or decreased the performances of previous experiences. Having negative values means forgetting. Here just for PNN and GEM, we have zero value and for the other methods, we have negative value. It is completely reasonable while we are comparing the ACC metric for these methods. Because just in the case of PNN and GEM we never forget the past.

# %% [markdown]
# **Conclusion**
#
#
# As far as we compared above, the best model for this benchmark is PNN. The PNN strategy doesn't forget the past and keeps learning over time. It is quite reasonable because the main feature of PNN is the focus on the forward transfer and re-use of previously acquired representational power. We are getting good accuracy but it's quite inefficient. the reason is that as far as we are using big models significantly the parameter space grows and is very difficult to scale on longer sequences of experiences. While we are comparing the PNN model RAM and CPU usage and running time this is completely obvious the model is expensive in terms of computation. All in all, while we do have not any limitations on resources having more ACC and not forgetting past tasks, and keep learning over time is more important for us.The next good method is GEM, which benefits both replay and regularization strategies. Here we have plasticity but we are forgetting the past experience by training on the new experience. After these, the other good methods are GDUMB and Replay. These strategies try to use past samples in new experiences and by doing so it helps to not forget the past. But as we see in these benchmarks the model had forgotten a bit the past knowledge.
